# %% [markdown]
# ## Build a list with unit dictionaries including below data
# - {
# - 'musicname' : 'original filename',
# - 'staff_id' : int,
# - 'start' : int, (number of start measure)
# - 'end' : int, (number of end measure)
# - 'tempo' : int,
# - 'timesig' : '4/4' or '6/8' or..., (time signature)
# - 'beats' : '1/4,0; 1/2,1; 1/8,1; 1/8,0', (假設為4/4拍，左為一單位的拍子，順序為：四分休止符、二分音符、八分音符、八分休止符，1/4 + 1/2 + 1/8 + 1/8 = 1) (實際上拍子長度為小數型式如0.25, 0.125, 0.0625)
# - 'instrument' : string, (此Staff代表的樂器)
# - 'instsrc' : string (此Staff選用的樂器)
# - }
#
# ## 演算法及注意事項
# - 不管同staff中偶爾出現的複數旋律，tag < track >
# - tempo取同單位中的最大值
# - 若同單位中發生time signature(ex: 4/4 to 6/8), 就是於第二或三或四小節發生拍子改變，則捨棄此單位
# - 關於記錄Staff所選用的樂器的'instsrc', mscx的metadata的< Part >中可能有多個< Channel >, 只記綠第一個< Channel >中< program value="number" >的number
#
# ## 休止符 tag < Rest>
# * 先將拍子長度存入BeatStr,
# * 之後發現連續的休止符再修改BeatStr,
# * 取出上個休止符長度，合併長度後覆蓋過BeatStr中上個休止符長度。
#
# ## 連結線 tag < Tie >
# - 先不將拍子長度存入BeatStr,
# - 並先將拍子長度存入暫存的tiedBeats,
# - 之後確認連結線結束後再將tiedBeats存入BeatStr.
#
# ## 多連音 tag < Tuplet >
# - 一組多連音必在同一小節內
# - 所有音符數量不一定等於actualNotes值
# - 所有音符長度相加後 * normalNotes值 / actualNotes值，即為實際長度
# - 發現一包含10個1/16或1/32音長的< Tuplet >會造成音長比較問題，須以 "差之絕對值小於約0.000000001" 取代 "相等" 之if判斷式
#
# ## 未來可簡化或重構的部分
# - timeSig change detection
# - 四小節單位結算部分
# - for else最末小節處理部分
#
# ## OOP in the future
# - MscxObj: self.staffList, self.tempoDic, self.instrumentDic, self.usedInstSrcDic
# - MscxObj: loopMeasure(), lastMeasure(), per4Measure(), genDataDic()
# - UnitObj: self.musicname, self.timesig, self.beats, self.tempo
# - UnitObj: self.start, self.end, self.staff_id, self.instrument
# - UnitObj: getTempo(), getInstrument(), getBeats(), ifChordOrRest(), ifDots()
# - UnitObj: ifTuplet(), ifTie(), ifTimeSigChanges(), lastRestOrNot()
# - UnitObj: pickleDump(), pickleLoad()
# - MainClass: mainList, beatDic, instSrcDic, fileLoopForADir, doubleCheck()

# %%
from bs4 import BeautifulSoup as bs
from decimal import *
import os
import sys
import pickle
import pymongo
import csv
from pymongo import MongoClient

#Beat dictionary
beatDic = {
    'measure':None,
    'whole':Decimal(1),
    'half':Decimal(1)/2,
    'quarter':Decimal(1)/4,
    'eighth':Decimal(1)/8,
    '16th':Decimal(1)/16,
    '32nd':Decimal(1)/32,
    '64th':Decimal(1)/64,
    '128th':Decimal(1)/128
}

#Build a instrument source dictionary
with open('C:/Users/BigData/git/DownloadMusic/instrument_table.csv','r') as infile:
    instSrcDic = dict(csv.reader(infile))

#Generate unit-data dictionary containing below properties
def genDataDic(staff_id, timeSig, beatStr, filename, start, end):
    beatStr = beatStr[:-1]
    if 'only1' in tempoDic:
        tempo = tempoDic['only1']
    else:
        tempo = tempoDic[end]
    return {
        'staff_id':staff_id,
        'timesig':timeSig,
        'beats':beatStr,
        'musicname':filename,
        'start':start,
        'end':end,
        'tempo':tempo,
        'instrument':instrumentDic[staff_id],
        'instsrc':instSrcDic[usedInstSrcDic[staff_id]]
    }

# %%
#Called by doLastMeasure() to simply the process
#of determination if Time Signature changed
def diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, mod, start, end, filename):
    if diffTimeSigs == False:
        if abs(unitBeatSum - beatDic['measure'] * mod) < 0.000000001:
            print 'beatStr: ' + beatStr
            print '------------------------------------'
            print 'True, unitBeatSum: ' + str(unitBeatSum)
            print '------------------------------------'
            mainList.append(genDataDic(staff, timeSig, beatStr, filename, start, end))
        else:
            print 'False, unitBeatSum: ' + str(unitBeatSum)
            sys.exit('Error: Incorrect sum of beats of a unit')        
    else:
        print 'Time Signature changed, ignore this unit.'
        print '------------------------------------'    

#Called by getBeats() to simplify the process handing last measure
def doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename):
    timeSig = str(sigN)+'/'+str(sigD)
    if i % 4 == 1:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 1, i, i, filename)
    elif i % 4 == 2:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 2, i-1, i, filename)
    elif i % 4 == 3:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 3, i-2, i, filename)
    else:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 4, i-3, i, filename)

# %%
#Called by countBeats() to determine if last note is a Rest
#whose beat should be merged with this Rest
def lastRestOrNot(beatStr, thisBeat):
    #If beatStr is False, it's the 1st note(Rest) of a unit
    if not beatStr:
        beatStr = str(thisBeat)+',0;'
    #If beatStr is True, it's not the 1st note(Rest) of a unit
    else:
        #If last note is a Rest
        if beatStr[-2] == '0':
            lastBeat = Decimal(beatStr.rsplit(';', 2)[-2].split(',')[0])
            combinedBeat = str(lastBeat + thisBeat)
            #beatStr contains equivalent to or more than 2 pairs
            if len(beatStr.rsplit(';', 2)) > 2:
                beatStr = beatStr.rsplit(';', 2)[-3] + ';' + combinedBeat + ',0;'
            #beatStr contains exactly 1 pair
            elif len(beatStr.rsplit(';', 2)) == 2:
                beatStr = combinedBeat + ',0;'
        #If last note is not a Rest
        else:
            beatStr += str(thisBeat)+',0;'
    return beatStr

#Called by countBeats() to handle tag <Tie>
def ifTie(beatStr, thisBeat, note, tiedBeats):
    #Totally 2*4=8 conditions
    if tiedBeats == 0:
        #No tie
        if not note.find('Tie') and not note.find('endSpanner'):
            beatStr += str(thisBeat) + ',1;'
        #Tie starts.
        elif note.find('Tie') and not note.find('endSpanner'):
            tiedBeats += thisBeat
        #Tie ends at start of a unit
        elif not note.find('Tie') and note.find('endSpanner'):
            beatStr += str(thisBeat) + ',1;'
        #Tie continues at start of a unit
        elif note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
    else: #if tiedBeats != 0:
        #It shouldn't happen. Just for debugging
        if not note.find('Tie') and not note.find('endSpanner'):
            sys.exit('tiedBeats != 0 and not Tie and not endSpanner')
        #It shouldn't happen. Just for debugging
        elif note.find('Tie') and not note.find('endSpanner'):
            sys.exit('tiedBeats != 0 and Tie and not endSpanner')
        #Tie ends
        elif not note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
            beatStr += str(tiedBeats) + ',1;'
            tiedBeats = 0
        #Tie continues
        elif note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
    return beatStr, tiedBeats

#Called by countBeats() to handle tag <dots>
def ifDots(note):
    if not note.find('dots'):
        multi = 1
    else:
        dots = note.find('dots').text
        if dots == '1':
            multi = 1.5
        elif dots == '2':
            multi = 1.75
        elif dots == '3':
            multi = 1.875
    return Decimal(multi)

#Called by countBeats to simplify the codes
def ifChordOrRest(note, beatSum, tupletID, tupletRatio):
    print note.name,
    key = note.find('durationType').text
    multi = ifDots(note)
    if note.find('Tuplet') and note.find('Tuplet').text == tupletID:
        multi *= tupletRatio
    thisBeat = beatDic[key] * Decimal(multi)
    beatSum += thisBeat
    return thisBeat, beatSum

#Called by getBeats() to count beats & accumulate the beat-string of a unit
def countBeats(measure, beatStr, unitBeatSum, tiedBeats):
    beatSum = 0
    tupletID = ''
    tupletRatio = 1
    for note in measure.find_all(['Chord','Rest','Tuplet'], recursive=False):
        if note.name == 'Chord' and not note.find('track'):
            thisBeat, beatSum = ifChordOrRest(note, beatSum, tupletID, tupletRatio)
            beatStr, tiedBeats = ifTie(beatStr, thisBeat, note, tiedBeats)
        elif note.name == 'Rest' and not note.find('track'):
            thisBeat, beatSum = ifChordOrRest(note, beatSum, tupletID, tupletRatio)
            beatStr = lastRestOrNot(beatStr, thisBeat)
        elif note.name == 'Tuplet':
            tupletID = note['id']
            normalNotes = Decimal(note.find('normalNotes').text)
            actualNotes = Decimal(note.find('actualNotes').text)
            tupletRatio = normalNotes / actualNotes
    if abs(beatSum - beatDic['measure']) < 0.000000001:
        print '\nTrue, beatSum: ' + str(beatSum)
        unitBeatSum += beatSum
        return beatStr, unitBeatSum, tiedBeats
    else:
        print '\nFalse, beatSum: ' + str(beatSum)
        print beatStr
        sys.exit('Error: Incorrect sum of beats of a measure')

# %%
#Called by main function in the loop for multiple mscx files
def getTempo(dirPath, filename):
    filePath = dirPath + filename
    with open(filePath, 'r') as f:
        mscx = bs(f.read(), 'xml')
        
    #Select measures of staff#1 because tempos only appear in staff#1
    staff1Measures = mscx.select('Score > Staff:nth-of-type(1) > Measure')
    
    #Get 1st tempo.
    tempo = int(staff1Measures[0].select('Tempo > text')[0].text.rsplit(' ', 1)[-1])
        
    #If there is only 1 tempo, no need to go through every measure.
    if len(mscx.select('Score > Staff:nth-of-type(1) Tempo')) == 1:
        tempoDic['only1'] = tempo
    elif len(mscx.select('Score > Staff:nth-of-type(1) Tempo')) > 1:
        tmp = []
        for i, measure in enumerate(staff1Measures[:-1], 1):
            for t in measure.select('Tempo > text'):
                tmp.append(int(t.text.rsplit(' ', 1)[-1]))
            if i % 4 == 0:
                if tmp:
                    tempo = max(tmp)
                tempoDic[i] = tempo
                del tmp[:]
        #Handle last-measure situations with for-else
        else:
            i += 1
            for t in staff1Measures[-1].select('Tempo > text'):
                tmp.append(int(t.text.rsplit(' ', 1)[-1]))
            if tmp:
                tempo = max(tmp)
            tempoDic[i] = tempo
    else:
        sys.exit('No Tempo found')

# %%
def doubleCheck(j, dic, mod):
    print '[Unit #'+str(j)+']'
    timeSig = Decimal(dic['timesig'].split('/')[0]) / Decimal(dic['timesig'].split('/')[1])
    unitBeatSum2 = 0
    for value in dic['beats'].split(';'):
        unitBeatSum2 += Decimal(value[:-2])
    if abs(unitBeatSum2 - timeSig * mod) < 0.000000001:
        print dic
        print '------------------------------------'
    else:
        print 'unitBeatSum2:', unitBeatSum2
        print 'timeSig * mod =', timeSig, '*', mod, '=', timeSig * mod
        sys.exit('FATAL: Incorrect sum of beats of a unit.\n\
        The 1st check passed but the 2nd failed.')
        print '------------------------------------'

# %%
#Called by main function in the loop for multiple mscx files
def getBeats(dirPath, filename, staffList, mainList):
    filePath = dirPath + filename
    with open(filePath, 'r') as f:
        mscx = bs(f.read(), 'xml')
#     if max(staffList) > len(mscx.select('Score > Staff')):
#         sys.exit('Error: Staff number out of range')
    filename = filename.rsplit('.', 1)[0]
    print 'Filename: ' + filename
    print '------------------------------------'
    
    #Build a represented instrument dictionary
    for part in mscx.find_all('Part'):
        staffID = []
        for tag in part.find_all(['Staff', 'instrumentId', 'program']):
            if tag.name == 'Staff':
                staffID.append(int(tag['id']))
            elif tag.name == 'instrumentId':
                for ID in staffID:
                    instrumentDic[ID] = str(tag.text)
            else:
                for ID in staffID:
                    usedInstSrcDic[ID] = str(tag['value'])
                break
        if not part.find('instrumentId'):
            for ID in staffID:
                instrumentDic[ID] = None
    
    #Get 1st time signature
    staff1TimeSig = mscx.select_one('Score > Staff:nth-of-type(1) TimeSig')
    sigN = Decimal(staff1TimeSig.find('sigN').text)
    sigD = Decimal(staff1TimeSig.find('sigD').text)
    beatDic['measure'] = sigN/sigD
    diffTimeSigs = False
    
    #目前不用stafflist, 讓做字典產生的getBeats()處理所有staffs
    #Main loop for each staff
#     for staff in staffList:
    for staff in range(1, len(mscx.select('Score > Staff'))+1):
        beatStr = ''
        unitBeatSum = 0
        tiedBeats = 0
        for i, measure in enumerate(mscx.select('Score > \
                              Staff:nth-of-type('+str(staff)+') > \
                              Measure')[:-1], 1):
            print '[Staff #'+str(staff)+', Measure #'+str(i)+']'
            
            #Determine Time Signature & detect if it changes
            if measure.find('TimeSig'):
                sigN = Decimal(measure.find('sigN').text)
                sigD = Decimal(measure.find('sigD').text)
                if sigN/sigD != beatDic['measure']:
                    beatDic['measure'] = sigN/sigD
                    if i % 4 == 2 or i % 4 == 3:
                        diffTimeSigs = True
                        continue
                    elif i % 4 == 0:
                        diffTimeSigs = False
                        beatStr = ''
                        unitBeatSum = 0
                        tiedBeats = 0
                        print 'Time Signature changed, ignore this unit.'
                        print '------------------------------------'
                        continue
                        
            #Count beats & accumulate the beat-string of a unit
            beatStr, unitBeatSum, tiedBeats = \
            countBeats(measure, beatStr, unitBeatSum, tiedBeats)
            
            #Generate a unit dictionary per 4 measures
            if i % 4 != 0:
                print 'beatStr: ' + beatStr
                print '------------------------------------'                
            else:
                if diffTimeSigs == True:
                    diffTimeSigs = False
                    beatStr = ''
                    print 'Time Signature changed, ignore this unit.'
                    print '------------------------------------'
                    continue
                if abs(unitBeatSum - beatDic['measure'] * 4) < 0.000000001:
                    timeSig = str(sigN)+'/'+str(sigD)
                    if tiedBeats != 0:
                        beatStr += str(tiedBeats) + ',1;'
                    mainList.append(genDataDic(staff, timeSig, beatStr, filename, i-3, i))
                    print 'beatStr: ' + beatStr
                    print '------------------------------------'
                    print 'True, unitBeatSum: ' + str(unitBeatSum)
                    print '------------------------------------'
                    tiedBeats = 0
                    beatStr = ''
                    unitBeatSum = 0
                else:
                    print 'False, unitBeatSum: ' + str(unitBeatSum)
                    sys.exit('Error: Incorrect sum of beats of a unit')
                    
        #Handle last-measure situations with for-else
        else:
            i += 1
            lastMeasure = mscx.select('Score > \
                                       Staff:nth-of-type('+str(staff)+') > \
                                       Measure')[-1]
            print '[Staff #'+str(staff)+', Measure #'+str(i)+']'
            if not lastMeasure.find('TimeSig'):
                beatStr, unitBeatSum, tiedBeats = \
                countBeats(lastMeasure, beatStr, unitBeatSum, tiedBeats)
                if tiedBeats != 0:
                    beatStr += str(tiedBeats) + ',1;'
                doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename)
            else:
                sigN = Decimal(lastMeasure.find('sigN').text)
                sigD = Decimal(lastMeasure.find('sigD').text)
                if sigN/sigD == beatDic['measure']:
                    beatStr, unitBeatSum, tiedBeats = \
                    countBeats(lastMeasure, beatStr, unitBeatSum, tiedBeats)
                    if tiedBeats != 0:
                        beatStr += str(tiedBeats) + ',1;'
                        doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename)
                else:
                    print 'Time Signature changed, ignore this unit.'
                    print '------------------------------------'

# %%
#Main function here
#目前不用stafflist, 讓做字典產生的getBeats()處理所有staffs
staffList = []

tempoDic = {}
instrumentDic = {}
usedInstSrcDic = {}
mainList = []
dirPath = 'C:/Users/BigData/Desktop/mscx/'
for filename in os.listdir(dirPath):
    getTempo(dirPath, filename)
    getBeats(dirPath, filename, staffList, mainList)
    tempoDic.clear()
    instrumentDic.clear()
    usedInstSrcDic.clear()

#Print dicts while double checking
for j, dic in enumerate(mainList, 1):
    mod = dic['end'] - dic['start'] + 1
    doubleCheck(j, dic, mod)

mainList2 = mainList
del mainList[:]
del staffList[:]
# Out:
# Filename: Basket Case
# ------------------------------------
# [Staff #1, Measure #1]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #2]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #1, Measure #3]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 2,0;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #4]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 2,0;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #5]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #6]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #7]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #8]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #9]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #10]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #11]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #12]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #13]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #14]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #1, Measure #15]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #16]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #17]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #18]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #19]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #20]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #21]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #22]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #23]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #24]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #25]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #26]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #27]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #28]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #29]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #30]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #31]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #32]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #33]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #34]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #35]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #36]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #37]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #38]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #39]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #40]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #41]
# Rest Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.0625,0;0.1875,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #42]
# Rest
# True, beatSum: 1
# beatStr: 0.0625,0;0.1875,1;1.75,0;
# ------------------------------------
# [Staff #1, Measure #43]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.0625,0;0.1875,1;1.75,0;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #44]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.0625,0;0.1875,1;1.75,0;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #45]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #46]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #47]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #48]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #49]
# Rest Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.0625,0;0.1875,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #50]
# Rest
# True, beatSum: 1
# beatStr: 0.0625,0;0.1875,1;1.75,0;
# ------------------------------------
# [Staff #1, Measure #51]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.0625,0;0.1875,1;1.75,0;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #52]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.0625,0;0.1875,1;1.75,0;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #53]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #54]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #55]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #56]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #57]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #58]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #59]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #60]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #61]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #62]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #63]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.5,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #64]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #65]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #66]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #67]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #68]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #69]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #70]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #71]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #72]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #73]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #74]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #75]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #76]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #77]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #78]
# Chord Rest Rest
# True, beatSum: 1.00
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #79]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.75,0;0.5,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #80]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.75,0;0.5,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #81]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #82]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #83]
# Rest Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #84]
# Rest
# True, beatSum: 1
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;1.75,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #85]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #86]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #87]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #88]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #89]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #90]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #91]
# Rest Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #92]
# Rest
# True, beatSum: 1
# beatStr: 0.25,1;0.25,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;1.75,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #93]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #94]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #95]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #96]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #97]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #98]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #99]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #100]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #101]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #102]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #103]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #104]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #105]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #1, Measure #106]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #107]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #108]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.25,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #109]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #110]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #111]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #112]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #113]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #114]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #115]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #116]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #117]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #118]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #119]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #120]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #121]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #122]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #123]
# Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.5,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #124]
# Chord
# True, beatSum: 1
# beatStr: 0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.5,1;0.375,1;1.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #125]
# Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #126]
# Chord
# True, beatSum: 1
# beatStr: 0.5,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #127]
# Chord
# True, beatSum: 1
# beatStr: 0.5,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #128]
# Chord
# True, beatSum: 1
# beatStr: 0.5,1;0.375,1;3.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #1, Measure #129]
# Chord
# True, beatSum: 1
# beatStr:
# ------------------------------------
# [Staff #1, Measure #130]
# Chord
# True, beatSum: 1
# beatStr:
# ------------------------------------
# [Staff #1, Measure #131]
# Chord
# True, beatSum: 1
# beatStr:
# ------------------------------------
# [Staff #1, Measure #132]
# Chord
# True, beatSum: 1
# beatStr: 4,1;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #1, Measure #133]
# Chord Rest Rest
# True, beatSum: 1.00
# beatStr: 0.25,1;0.75,0;
# ------------------------------------
# True, unitBeatSum: 1.00
# ------------------------------------
# [Staff #2, Measure #1]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #2]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #3]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #4]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #5]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #6]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #7]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #8]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #9]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #10]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #11]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #12]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #13]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #14]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #15]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #16]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #17]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #18]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #19]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #20]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #21]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #22]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #23]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #24]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #25]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #26]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #27]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #28]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #29]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #30]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #31]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #32]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #2, Measure #33]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Rest Rest
# True, beatSum: 0.9999999999999999999999999996
# beatStr: 0.125,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.625,0;
# ------------------------------------
# [Staff #2, Measure #34]
# Rest Rest Rest Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;1.500,0;
# ------------------------------------
# [Staff #2, Measure #35]
# Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;1.500,0;1.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #36]
# Chord Chord Chord Chord Chord Chord Chord Chord Rest Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.125,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;0.02083333333333333333333333333,1;1.500,0;1.0625,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.0625,1;0.125,1;0.0625,1;0.1875,1;0.008928571428571428571428571430,0;0.008928571428571428571428571430,1;0.008928571428571428571428571430,1;0.01785714285714285714285714286,1;0.008928571428571428571428571430,1;0.008928571428571428571428571430,1;0.008928571428571428571428571430,1;0.008928571428571428571428571430,1;0.008928571428571428571428571430,1;0.01785714285714285714285714286,1;0.008928571428571428571428571430,1;0.07142857142857142857142857143,1;0.01041666666666666666666666667,1;0.01041666666666666666666666667,1;0.01041666666666666666666666667,1;0.01041666666666666666666666667,1;0.01041666666666666666666666667,1;0.01041666666666666666666666667,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #2, Measure #37]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #38]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #39]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #40]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #2, Measure #41]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #42]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #43]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #44]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #2, Measure #45]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #46]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #47]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #48]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #2, Measure #49]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #50]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #51]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #52]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000
# ------------------------------------
# [Staff #2, Measure #53]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #54]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #55]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #56]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #57]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #58]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #59]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# ...
# ------------------------------------
# [Unit #64]
# {'musicname': 'Basket Case', 'staff_id': 2, 'end': 120, 'timesig': '4/4', 'start': 117, 'instrument': 'pluck.bass', 'tempo': 168, 'beats': '0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Electric Bass (pick)'}
# ------------------------------------
# [Unit #65]
# {'musicname': 'Basket Case', 'staff_id': 2, 'end': 124, 'timesig': '4/4', 'start': 121, 'instrument': 'pluck.bass', 'tempo': 168, 'beats': '0.25,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.250,1;0.125,1;0.125,1;0.125,1;0.5,1;0.375,1;1.125,1', 'instsrc': 'Electric Bass (pick)'}
# ------------------------------------
# [Unit #66]
# {'musicname': 'Basket Case', 'staff_id': 2, 'end': 128, 'timesig': '4/4', 'start': 125, 'instrument': 'pluck.bass', 'tempo': 168, 'beats': '0.5,1;0.375,1;3.125,1', 'instsrc': 'Electric Bass (pick)'}
# ------------------------------------
# [Unit #67]
# {'musicname': 'Basket Case', 'staff_id': 2, 'end': 132, 'timesig': '4/4', 'start': 129, 'instrument': 'pluck.bass', 'tempo': 168, 'beats': '4,1', 'instsrc': 'Electric Bass (pick)'}
# ------------------------------------
# [Unit #68]
# {'musicname': 'Basket Case', 'staff_id': 2, 'end': 133, 'timesig': '4/4', 'start': 133, 'instrument': 'pluck.bass', 'tempo': 168, 'beats': '0.25,1;0.75,0', 'instsrc': 'Electric Bass (pick)'}
# ------------------------------------
# [Unit #69]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 4, 'timesig': '4/4', 'start': 1, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.25,0;0.25,1;0.25,0;0.25,1;0.25,1;0.125,1;0.125,1;0.25,1;2,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #70]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 8, 'timesig': '4/4', 'start': 5, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '4,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #71]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 12, 'timesig': '4/4', 'start': 9, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '4,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #72]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 16, 'timesig': '4/4', 'start': 13, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '4,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #73]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 20, 'timesig': '4/4', 'start': 17, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '1.875,0;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #74]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 24, 'timesig': '4/4', 'start': 21, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #75]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 28, 'timesig': '4/4', 'start': 25, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #76]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 32, 'timesig': '4/4', 'start': 29, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.1875,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #77]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 36, 'timesig': '4/4', 'start': 33, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;1.50,0;0.25,1;0.25,0;0.25,1;0.25,0;0.1875,1;0.03125,1;0.03125,1;0.125,1;0.03125,1;0.03125,1;0.0625,1;0.0625,0;0.03125,1;0.03125,1;0.125,1;0.0625,1;0.03125,1;0.03125,1;0.125,0;0.03125,1;0.09375,1;0.125,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #78]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 40, 'timesig': '4/4', 'start': 37, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #79]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 44, 'timesig': '4/4', 'start': 41, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #80]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 48, 'timesig': '4/4', 'start': 45, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #81]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 52, 'timesig': '4/4', 'start': 49, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.125,0;0.0625,1;0.0625,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #82]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 56, 'timesig': '4/4', 'start': 53, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #83]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 60, 'timesig': '4/4', 'start': 57, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #84]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 64, 'timesig': '4/4', 'start': 61, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #85]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 68, 'timesig': '4/4', 'start': 65, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #86]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 72, 'timesig': '4/4', 'start': 69, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.03125,1;0.09375,1;0.125,0;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #87]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 76, 'timesig': '4/4', 'start': 73, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #88]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 80, 'timesig': '4/4', 'start': 77, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.03125,1;0.09375,1;0.125,1;0.03125,1;0.09375,1;0.125,1;0.03125,1;0.09375,1;0.125,1;0.03125,1;0.09375,1;0.125,1;0.03125,1;0.09375,1;0.625,0;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #89]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 84, 'timesig': '4/4', 'start': 81, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #90]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 88, 'timesig': '4/4', 'start': 85, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #91]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 92, 'timesig': '4/4', 'start': 89, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #92]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 96, 'timesig': '4/4', 'start': 93, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #93]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 100, 'timesig': '4/4', 'start': 97, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #94]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 104, 'timesig': '4/4', 'start': 101, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #95]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 108, 'timesig': '4/4', 'start': 105, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #96]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 112, 'timesig': '4/4', 'start': 109, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.03125,1;0.09375,1;0.125,1;0.1250000000000000000000000000,1;0.125,1;0.1250000000000000000000000000,1;0.125,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #97]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 116, 'timesig': '4/4', 'start': 113, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,0;0.0625,1;0.0625,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #98]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 120, 'timesig': '4/4', 'start': 117, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.03125,1;0.09375,1;0.125,1;0.1250000000000000000000000000,1;0.125,1;0.1250000000000000000000000000,1;0.125,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #99]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 124, 'timesig': '4/4', 'start': 121, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.25,0;0.25,1;0.25,1;0.25,1', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #100]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 128, 'timesig': '4/4', 'start': 125, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '0.25,1;0.03125,1;0.09375,1;0.125,0;0.25,1;0.125,0;0.375,1;2.75,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #101]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 132, 'timesig': '4/4', 'start': 129, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '4,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------
# [Unit #102]
# {'musicname': 'Basket Case', 'staff_id': 3, 'end': 133, 'timesig': '4/4', 'start': 133, 'instrument': 'drum.group.set', 'tempo': 168, 'beats': '1,0', 'instsrc': 'Drawbar Organ'}
# ------------------------------------

# %%
#Store data into MongoDB
client = MongoClient('mongodb://10.120.30.8:27017')
db = client['music']
collect = db['tempo_beats']
collect.insert_many(mainList2)
del mainList2[:]

# %%
#Query MongoDB
cur = collect.find({'staff_id':5},{'_id':0,'musicname':1,'beats':1})
for i, item in enumerate(cur):
    print i, item
    print '------------------------------------'
