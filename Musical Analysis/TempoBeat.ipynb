# %% [markdown]
# ## Build a list with unit dictionaries including below data
# - {
# - 'musicname' : 'original filename',
# - 'staff_id' : int,
# - 'start' : int,
# - 'end' : int,
# - 'tempo' : int,
# - 'timesig' : '4/4' or '6/8' or...,
# - 'beats' : '1/4,0; 1/2,1; 1/8,1; 1/8,0' (假設為4/4拍，左為一單位的拍子，順序為：四分休止符、二分音符、八分音符、八分休止符，1/4 + 1/2 + 1/8 + 1/8 = 1) (實際上拍子長度為小數型式如0.25, 0.125, 0.0625)
# - 'instrument' : string
# - }
#
# ## 演算法及注意事項
# - 不管同staff中偶爾出現的複數旋律，tag < track >
# - tempo取同單位中的最大值
# - 若同單位中發生time signature(ex: 4/4 to 6/8), 就是於第二或三或四小節發生拍子改變，則捨棄此單位
#
# ## 休止符 tag < Rest>
# * 先將拍子長度存入BeatStr,
# * 之後發現連續的休止符再修改BeatStr,
# * 取出上個休止符長度，合併長度後覆蓋過BeatStr中上個休止符長度。
#
# ## 連結線 tag < Tie >
# - 先不將拍子長度存入BeatStr,
# - 並先將拍子長度存入暫存的tiedBeats,
# - 之後確認連結線結束後再將tiedBeats存入BeatStr.
#
# ## 多連音 tag < Tuplet >
# - 一組多連音必在同一小節內
# - 所有音符數量不一定等於actualNotes值
# - 所有音符長度相加後 * normalNotes值 / actualNotes值，即為實際長度
# - 發現一包含10個1/16或1/32音長的< Tuplet >會造成音長比較問題，須以 "差之絕對值小於約0.000000001" 取代 "相等" 之比較。
#
# ## 未來可簡化或重新思考流程、結構的部分
# - timeSig change detection
# - 四小節單位結算部分
# - for else最末小節處理部分

# %%
from bs4 import BeautifulSoup as bs
from decimal import *
import os
import sys
import pickle
import pymongo
from pymongo import MongoClient

#Beat dictionary
beatDic = {
           'measure':None,
           'whole':Decimal(1),
           'half':Decimal(1)/2,
           'quarter':Decimal(1)/4,
           'eighth':Decimal(1)/8,
           '16th':Decimal(1)/16,
           '32nd':Decimal(1)/32,
           '64th':Decimal(1)/64,
           '128th':Decimal(1)/128,
           '256th':Decimal(1)/256
          }

#Generate unit-data dictionary containing below properties
def genDataDic(staff_id, timeSig, beatStr, filename, start, end):
    beatStr = beatStr[:-1]
    if 'only1' in tempoDic:
        tempo = tempoDic['only1']
    else:
        tempo = tempoDic[end]
    return {'staff_id':staff_id, 'timesig':timeSig, 'beats':beatStr,\
            'musicname':filename, 'start':start, 'end':end, 'tempo':tempo,\
            'instrument':str(instrumentDic[staff_id])}

#Called by doLastMeasure() to simply the process
#of determination if Time Signature changed
def diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, mod, start, end, filename):
    if diffTimeSigs == False:
        if abs(unitBeatSum - beatDic['measure'] * mod) < 0.000000001:
            print 'beatStr: ' + beatStr
            print '------------------------------------'
            print 'True, unitBeatSum: ' + str(unitBeatSum)
            print '------------------------------------'
            mainList.append(genDataDic(staff, timeSig, beatStr, filename, start, end))
        else:
            print 'False, unitBeatSum: ' + str(unitBeatSum)
            sys.exit('Error: Incorrect sum of beats of a unit')        
    else:
        print 'Time Signature changed, omit this unit.'
        print '------------------------------------'    

#Called by getBeats() to simplify the process handing last measure
def doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename):
    timeSig = str(sigN)+'/'+str(sigD)
    if i % 4 == 1:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 1, i, i, filename)
    elif i % 4 == 2:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 2, i-1, i, filename)
    elif i % 4 == 3:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 3, i-2, i, filename)
    else:
        diffTimeSigsOrNot(staff, diffTimeSigs, timeSig, beatStr, unitBeatSum, 4, i-3, i, filename)

# %%
#Called by countBeats() to determine if last note is a Rest
#whose beat should be merged with this Rest
def lastRestOrNot(beatStr, thisBeat):
    #If beatStr is False, it's the first note(Rest) of a unit
    if not beatStr:
        beatStr = str(thisBeat)+',0;'
    #If beatStr is True, it's not the first note(Rest) of a unit
    else:
        #If last note is a Rest
        if beatStr[-2] == '0':
            lastBeat = Decimal(beatStr.rsplit(';', 2)[-2].split(',')[0])
            combinedBeat = str(lastBeat + thisBeat)
            #beatStr contains equivalent to or more than 2 pairs
            if len(beatStr.rsplit(';', 2)) > 2:
                beatStr = beatStr.rsplit(';', 2)[-3] + ';' + combinedBeat + ',0;'
            #beatStr contains exactly 1 pair
            elif len(beatStr.rsplit(';', 2)) == 2:
                beatStr = combinedBeat + ',0;'
        #If last note is not a Rest
        else:
            beatStr += str(thisBeat)+',0;'
    return beatStr

#Called by countBeats() to handle tag <Tie>
def ifTie(beatStr, thisBeat, note, tiedBeats):
    #Totally 2*4=8 conditions
    if tiedBeats == 0:
        #No tie
        if not note.find('Tie') and not note.find('endSpanner'):
            beatStr += str(thisBeat) + ',1;'
        #Tie starts.
        elif note.find('Tie') and not note.find('endSpanner'):
            tiedBeats += thisBeat
        #Tie ends at start of a unit
        elif not note.find('Tie') and note.find('endSpanner'):
            beatStr += str(thisBeat) + ',1;'
        #Tie continues at start of a unit
        elif note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
    else: #if tiedBeats != 0:
        #It shouldn't happen. Just for debugging
        if not note.find('Tie') and not note.find('endSpanner'):
            sys.exit('tiedBeats != 0 and not Tie and not endSpanner')
        #It shouldn't happen. Just for debugging
        elif note.find('Tie') and not note.find('endSpanner'):
            sys.exit('tiedBeats != 0 and Tie and not endSpanner')
        #Tie ends
        elif not note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
            beatStr += str(tiedBeats) + ',1;'
            tiedBeats = 0
        #Tie continues
        elif note.find('Tie') and note.find('endSpanner'):
            tiedBeats += thisBeat
    return beatStr, tiedBeats

#Called by countBeats() to handle tag <dots>
def ifDots(note):
    if not note.find('dots'):
        multi = 1
    else:
        dots = int(note.find('dots').text)
        if dots == 1:
            multi = 1.5
        elif dots == 2:
            multi = 1.75
        elif dots == 3:
            multi = 1.875
    return Decimal(multi)

#Called by countBeats to simplify the codes
def ifChordOrRest(note, beatSum, tupletID, tupletRatio):
    print note.name,
    key = note.find('durationType').text
    multi = ifDots(note)
    if note.find('Tuplet') and note.find('Tuplet').text == tupletID:
        multi *= tupletRatio
    thisBeat = beatDic[key] * Decimal(multi)
    beatSum += thisBeat
    return thisBeat, beatSum

#Called by getBeats() to count beats & accumulate the beat-string of a unit
def countBeats(measure, beatStr, unitBeatSum, tiedBeats):
    beatSum = 0
    tupletID = ''
    tupletRatio = 1
    for note in measure.children:
        if str(type(note)) == '<class \'bs4.element.Tag\'>':
            if note.name == 'Chord' and not note.find('track'):
                thisBeat, beatSum = ifChordOrRest(note, beatSum, tupletID, tupletRatio)
                beatStr, tiedBeats = ifTie(beatStr, thisBeat, note, tiedBeats)
            elif note.name == 'Rest' and not note.find('track'):
                thisBeat, beatSum = ifChordOrRest(note, beatSum, tupletID, tupletRatio)
                beatStr = lastRestOrNot(beatStr, thisBeat)
            elif note.name == 'Tuplet':
                tupletID = note['id']
                normalNotes = Decimal(note.find('normalNotes').text)
                actualNotes = Decimal(note.find('actualNotes').text)
                tupletRatio = normalNotes / actualNotes
    if abs(beatSum - beatDic['measure']) < 0.000000001:
        print '\nTrue, beatSum: ' + str(beatSum)
        unitBeatSum += beatSum
        return beatStr, unitBeatSum, tiedBeats
    else:
        print '\nFalse, beatSum: ' + str(beatSum)
        print beatStr
        sys.exit('Error: Incorrect sum of beats of a measure')

# %%
def getTempo(dirPath, filename):
    filePath = dirPath + filename
    with open(filePath, 'r') as f:
        mscx = bs(f.read(), 'xml')
        
    #Select measures of staff#1 because tempos only appear in staff#1
    staff1Measures = mscx.select('Score > Staff:nth-of-type(1) > Measure')
    
    #Get 1st tempo.
    tempo = int(staff1Measures[0].select('Tempo > text')[0].text.rsplit(' ', 1)[-1])
        
    #If there is only 1 tempo, no need to go through every measure.
    if len(mscx.select('Score > Staff:nth-of-type(1) Tempo')) == 1:
        tempoDic['only1'] = tempo
    elif len(mscx.select('Score > Staff:nth-of-type(1) Tempo')) > 1:
        tmp = []
        for i, measure in enumerate(staff1Measures[:-1], 1):
            for t in measure.select('Tempo > text'):
                tmp.append(int(t.text.rsplit(' ', 1)[-1]))
            if i % 4 == 0:
                if tmp:
                    tempo = max(tmp)
                tempoDic[i] = tempo
                del tmp[:]
        #Handle last-measure situations with for-else
        else:
            i += 1
            for t in staff1Measures[-1].select('Tempo > text'):
                tmp.append(int(t.text.rsplit(' ', 1)[-1]))
            if tmp:
                tempo = max(tmp)
            tempoDic[i] = tempo
    else:
        sys.exit('No Tempo found')

# %%
def getBeats(dirPath, filename, staffList, mainList):
    filePath = dirPath + filename
    with open(filePath, 'r') as f:
        mscx = bs(f.read(), 'xml')
#     if max(staffList) > len(mscx.select('Score > Staff')):
#         sys.exit('Error: Staff number out of range')
    filename = filename.rsplit('.', 1)[0]
    print 'Filename: ' + filename
    print '------------------------------------'
    
    #Build a instrument dictionary
    for part in mscx.select('Part'):
        staffID = []
        for tag in part.children:
            if str(type(tag)) == '<class \'bs4.element.Tag\'>':
                if tag.name == 'Staff':
                    staffID.append(int(tag['id']))
                elif tag.name == 'Instrument':
                    for ID in staffID:
                        if tag.find('instrumentId'):
                            instrumentDic[ID] = str(tag.find('instrumentId').text)
                        else:
                            instrumentDic[ID] = None
    
    #Get 1st time signature
    staff1TimeSig = mscx.select_one('Score > Staff:nth-of-type(1) TimeSig')
    sigN = int(staff1TimeSig.find('sigN').text)
    sigD = int(staff1TimeSig.find('sigD').text)
    beatDic['measure'] = Decimal(sigN)/sigD
    diffTimeSigs = False
    
    #目前不用stafflist, 讓做字典產生的getBeats()處理所有staffs
    #Main loop for each staff
#     for staff in staffList:
    for staff in range(1, len(mscx.select('Score > Staff'))+1):
        beatStr = ''
        unitBeatSum = 0
        tiedBeats = 0
        for i, measure in enumerate(mscx.select('Score > \
                              Staff:nth-of-type('+str(staff)+') > \
                              Measure')[:-1], 1):
            print '[Staff #'+str(staff)+', Measure #'+str(i)+']'
            
            #Determine Time Signature & detect if it changes
            if measure.find('TimeSig'):
                sigN = int(measure.find('sigN').text)
                sigD = int(measure.find('sigD').text)
                if Decimal(sigN)/sigD != beatDic['measure']:
                    beatDic['measure'] = Decimal(sigN)/sigD
                    if i % 4 == 2 or i % 4 == 3:
                        diffTimeSigs = True
                        continue
                    elif i % 4 == 0:
                        diffTimeSigs = False
                        beatStr = ''
                        unitBeatSum = 0
                        tiedBeats = 0
                        print 'Time Signature changed, omit this unit.'
                        print '------------------------------------'
                        continue
                        
            #Count beats & accumulate the beat-string of a unit
            beatStr, unitBeatSum, tiedBeats = \
            countBeats(measure, beatStr, unitBeatSum, tiedBeats)
            
            #Generate a unit dictionary per 4 measures
            if i % 4 != 0:
                print 'beatStr: ' + beatStr
                print '------------------------------------'                
            else:
                if diffTimeSigs == True:
                    diffTimeSigs = False
                    beatStr = ''
                    print 'Time Signature changed, omit this unit.'
                    print '------------------------------------'
                    continue
                if abs(unitBeatSum - beatDic['measure'] * 4) < 0.000000001:
                    timeSig = str(sigN)+'/'+str(sigD)
                    if tiedBeats != 0:
                        beatStr += str(tiedBeats) + ',1;'
                    mainList.append(genDataDic(staff, timeSig, beatStr, filename, i-3, i))
                    print 'beatStr: ' + beatStr
                    print '------------------------------------'
                    print 'True, unitBeatSum: ' + str(unitBeatSum)
                    print '------------------------------------'
                    tiedBeats = 0
                    beatStr = ''
                    unitBeatSum = 0
                else:
                    print 'False, unitBeatSum: ' + str(unitBeatSum)
                    sys.exit('Error: Incorrect sum of beats of a unit')
                    
        #Handle last-measure situations with for-else
        else:
            i += 1
            lastMeasure = mscx.select('Score > \
                                       Staff:nth-of-type('+str(staff)+') > \
                                       Measure')[-1]
            print '[Staff #'+str(staff)+', Measure #'+str(i)+']'
            if not lastMeasure.find('TimeSig'):
                beatStr, unitBeatSum, tiedBeats = \
                countBeats(lastMeasure, beatStr, unitBeatSum, tiedBeats)
                if tiedBeats != 0:
                    beatStr += str(tiedBeats) + ',1;'
                doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename)
            else:
                sigN = int(lastMeasure.find('sigN').text)
                sigD = int(lastMeasure.find('sigD').text)
                if Decimal(sigN)/sigD == beatDic['measure']:
                    beatStr, unitBeatSum, tiedBeats = \
                    countBeats(lastMeasure, beatStr, unitBeatSum, tiedBeats)
                    if tiedBeats != 0:
                        beatStr += str(tiedBeats) + ',1;'
                        doLastMeasure(staff, i, diffTimeSigs, sigN, sigD, beatStr, unitBeatSum, filename)
                else:
                    print 'Time Signature changed, omit this unit.'
                    print '------------------------------------'

# %%
def secondCheck(j, dic, mod):
    print '[Unit #'+str(j)+']'
    timeSig = Decimal(dic['timesig'].split('/')[0]) / Decimal(dic['timesig'].split('/')[1])
    unitBeatSum2 = 0
    for value in dic['beats'].split(';'):
        unitBeatSum2 += Decimal(value[:-2])
    if abs(unitBeatSum2 - timeSig * mod) < 0.000000001:
        print dic
        print '------------------------------------'
    else:
        print 'unitBeatSum2:', unitBeatSum2
        print 'timeSig * mod =', timeSig, '*', mod, '=', timeSig * mod
        sys.exit('FATAL: Incorrect sum of beats of a unit.\n\
        The first check passed but the 2nd failed.')
        print '------------------------------------'

# %%
## main function here
#目前不用stafflist, 讓做字典產生的getBeats()處理所有staffs
staffList = []

tempoDic = {}
instrumentDic = {}
mainList = []
dirPath = 'C:/Users/BigData/Desktop/mscx/'
for filename in os.listdir(dirPath):
    getTempo(dirPath, filename)
    getBeats(dirPath, filename, staffList, mainList)
    tempoDic.clear()
    instrumentDic.clear()

#Print dicts in 2nd check
# for j, dic in enumerate(mainList, 1):
#     mod = dic['end'] - dic['start'] + 1
#     secondCheck(j, dic, mod)

mainList2 = mainList
del mainList[:]
del staffList[:]
# Out:
# Filename: Any Time You Need A Friend
# ------------------------------------
# [Staff #1, Measure #1]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #2]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #1, Measure #3]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #1, Measure #4]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #1, Measure #5]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #6]
# Rest Rest Rest Rest Rest Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000000
# beatStr: 1.2421875,0;0.0078125,1;0.125,1;0.0625,1;0.1250,1;
# ------------------------------------
# [Staff #1, Measure #7]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 1.2421875,0;0.0078125,1;0.125,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.4375,1;
# ------------------------------------
# [Staff #1, Measure #8]
# Rest Rest Rest Chord Chord Rest Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000
# beatStr: 1.2421875,0;0.0078125,1;0.125,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.4375,1;0.171875,0;0.046875,1;0.03125,0;0.125,1;0.0625,1;0.1250,1;0.4375,1;
# ------------------------------------
# True, unitBeatSum: 4.0000000
# ------------------------------------
# [Staff #1, Measure #9]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.2500,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #10]
# Rest Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.2500,1;0.0625,1;0.125,1;0.25,0;0.125,1;0.0625,1;0.1250,1;0.4375,1;
# ------------------------------------
# [Staff #1, Measure #11]
# Rest Rest Rest Chord Chord Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.2500,1;0.0625,1;0.125,1;0.25,0;0.125,1;0.0625,1;0.1250,1;0.4375,1;0.4375,0;0.3750,1;0.1875,0;
# ------------------------------------
# [Staff #1, Measure #12]
# Rest
# True, beatSum: 1
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.2500,1;0.0625,1;0.125,1;0.25,0;0.125,1;0.0625,1;0.1250,1;0.4375,1;0.4375,0;0.3750,1;1.1875,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #13]
# Rest Rest Chord Rest
# True, beatSum: 1.0000
# beatStr: 0.5625,0;0.1875,1;0.25,0;
# ------------------------------------
# [Staff #1, Measure #14]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5625,0;0.1875,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.3125,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #15]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5625,0;0.1875,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.3125,1;0.125,1;0.375,1;0.125,1;0.1875,1;0.0625,1;0.3125,1;0.0625,1;
# ------------------------------------
# [Staff #1, Measure #16]
# Rest
# True, beatSum: 1
# beatStr: 0.5625,0;0.1875,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.3125,1;0.125,1;0.375,1;0.125,1;0.1875,1;0.0625,1;0.3125,1;0.0625,1;1,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #1, Measure #17]
# Rest Rest Rest Rest Chord Rest Rest
# True, beatSum: 1.000000
# beatStr: 0.234375,0;0.015625,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #18]
# Rest
# True, beatSum: 1
# beatStr: 0.234375,0;0.015625,1;1.75,0;
# ------------------------------------
# [Staff #1, Measure #19]
# Rest Rest Rest Rest Rest Chord Rest Rest
# True, beatSum: 1.0000000
# beatStr: 0.234375,0;0.015625,1;1.9921875,0;0.0078125,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #20]
# Rest
# True, beatSum: 1
# beatStr: 0.234375,0;0.015625,1;1.9921875,0;0.0078125,1;1.75,0;
# ------------------------------------
# True, unitBeatSum: 4.0000000
# ------------------------------------
# [Staff #1, Measure #21]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.125,1;0.1875,1;0.1875,1;0.125,1;
# ------------------------------------
# [Staff #1, Measure #22]
# Rest Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.125,1;0.1875,1;0.1875,1;0.125,1;0.0625,0;0.1875,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #23]
# Rest Rest Rest Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.375,1;0.125,1;0.1875,1;0.1875,1;0.125,1;0.0625,0;0.1875,1;0.9791666666666666666666666667,0;0.02083333333333333333333333333,1;0.125,1;0.0625,1;0.1250,1;
# ------------------------------------
# [Staff #1, Measure #24]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.375,1;0.125,1;0.1875,1;0.1875,1;0.125,1;0.0625,0;0.1875,1;0.9791666666666666666666666667,0;0.02083333333333333333333333333,1;0.125,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1458333333333333333333333333,1;0.4166666666666666666666666667,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #25]
# Rest Rest Rest Rest Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;
# ------------------------------------
# [Staff #1, Measure #26]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #27]
# Rest Rest Rest Rest Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.0625,1;0.375,1;0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;0.4375,1;
# ------------------------------------
# [Staff #1, Measure #28]
# Rest Rest Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;0.6250,1;0.0625,1;0.125,1;0.0625,1;0.1250,1;0.0625,1;0.375,1;0.2395833333333333333333333333,0;0.1354166666666666666666666667,1;0.0625,1;0.1250,1;0.4375,1;0.1875,0;0.0625,1;0.125,1;0.0625,1;0.3750,1;0.0625,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #29]
# Rest Rest Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.1875,0;0.0625,1;0.01041666666666666666666666667,1;0.1145833333333333333333333333,1;0.0625,1;0.1250,1;0.4375,1;
# ------------------------------------
# [Staff #1, Measure #30]
# Rest
# True, beatSum: 1
# beatStr: 0.1875,0;0.0625,1;0.01041666666666666666666666667,1;0.1145833333333333333333333333,1;0.0625,1;0.1250,1;0.4375,1;1,0;
# ------------------------------------
# [Staff #1, Measure #31]
# Rest
# True, beatSum: 1
# beatStr: 0.1875,0;0.0625,1;0.01041666666666666666666666667,1;0.1145833333333333333333333333,1;0.0625,1;0.1250,1;0.4375,1;2,0;
# ------------------------------------
# [Staff #1, Measure #32]
# Rest Chord Rest
# True, beatSum: 1.00
# beatStr: 0.1875,0;0.0625,1;0.01041666666666666666666666667,1;0.1145833333333333333333333333,1;0.0625,1;0.1250,1;0.4375,1;2.5,0;0.25,1;0.25,0;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #33]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #34]
# Rest Rest Rest Rest Chord Chord Rest Rest Rest Rest Chord
# True, beatSum: 1.0000000
# beatStr: 1.2109375,0;0.0156250,1;0.3984375,0;0.375,1;
# ------------------------------------
# [Staff #1, Measure #35]
# Rest
# True, beatSum: 1
# beatStr: 1.2109375,0;0.0156250,1;0.3984375,0;0.375,1;1,0;
# ------------------------------------
# [Staff #1, Measure #36]
# Rest Rest Rest Chord Rest Rest Chord
# True, beatSum: 1.00000
# beatStr: 1.2109375,0;0.0156250,1;0.3984375,0;0.375,1;1.21875,0;0.03125,1;0.375,0;0.375,1;
# ------------------------------------
# True, unitBeatSum: 4.0000000
# ------------------------------------
# [Staff #1, Measure #37]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #38]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 1,0;0.3333333333333333333333333333,1;0.1250000000000000000000000000,1;0.2083333333333333333333333334,1;0.1666666666666666666666666667,1;0.1666666666666666666666666667,1;
# ------------------------------------
# [Staff #1, Measure #39]
# Rest Chord Chord Chord Chord Chord Rest Rest
# True, beatSum: 1.000000000000000000000000000
# beatStr: 1,0;0.3333333333333333333333333333,1;0.1250000000000000000000000000,1;0.2083333333333333333333333334,1;0.1666666666666666666666666667,1;0.1666666666666666666666666667,1;0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.6875,1;0.1875,0;
# ------------------------------------
# [Staff #1, Measure #40]
# Rest Rest Rest Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 1,0;0.3333333333333333333333333333,1;0.1250000000000000000000000000,1;0.2083333333333333333333333334,1;0.1666666666666666666666666667,1;0.1666666666666666666666666667,1;0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.6875,1;0.59375,0;0.06250000000000000000000000000,1;0.2812500000000000000000000000,1;0.08333333333333333333333333334,1;0.1666666666666666666666666667,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #41]
# Chord Chord Chord Rest
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.08333333333333333333333333334,1;0.4166666666666666666666666667,1;0.5,0;
# ------------------------------------
# [Staff #1, Measure #42]
# Rest Rest Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.08333333333333333333333333334,1;0.4166666666666666666666666667,1;0.7916666666666666666666666667,0;0.04166666666666666666666666667,1;0.4166666666666666666666666667,1;0.08333333333333333333333333334,1;
# ------------------------------------
# [Staff #1, Measure #43]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.08333333333333333333333333334,1;0.4166666666666666666666666667,1;0.7916666666666666666666666667,0;0.04166666666666666666666666667,1;0.4166666666666666666666666667,1;0.08333333333333333333333333334,1;0.2666666666666666666666666667,1;0.1000,1;0.200,1;0.1000,1;0.5,1;
# ------------------------------------
# [Staff #1, Measure #44]
# Rest Rest Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.08333333333333333333333333334,1;0.4166666666666666666666666667,1;0.7916666666666666666666666667,0;0.04166666666666666666666666667,1;0.4166666666666666666666666667,1;0.08333333333333333333333333334,1;0.2666666666666666666666666667,1;0.1000,1;0.200,1;0.1000,1;0.5,1;0.3125,0;0.125,1;0.1625,1;0.200,1;0.1000,1;0.1000,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #45]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.125,1;0.125,1;0.08333333333333333333333333334,1;0.2291666666666666666666666667,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #1, Measure #46]
# Rest Chord Chord Chord Chord Chord Chord Chord Rest Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.125,1;0.125,1;0.08333333333333333333333333334,1;0.2291666666666666666666666667,1;0.0625,1;0.375,1;0.1000,0;0.05000,1;0.15000,1;0.1000,1;0.1416666666666666666666666667,1;0.1250000000000000000000000000,1;0.08333333333333333333333333334,1;0.0625,0;0.1875,1;
# ------------------------------------
# [Staff #1, Measure #47]
# Chord Rest Rest Rest Rest Chord Chord Rest Rest
# True, beatSum: 1.00000
# beatStr: 0.125,1;0.125,1;0.08333333333333333333333333334,1;0.2291666666666666666666666667,1;0.0625,1;0.375,1;0.1000,0;0.05000,1;0.15000,1;0.1000,1;0.1416666666666666666666666667,1;0.1250000000000000000000000000,1;0.08333333333333333333333333334,1;0.0625,0;0.1875,1;0.25,1;0.46875,0;0.09375,1;0.1875,0;
# ------------------------------------
# [Staff #1, Measure #48]
# Time Signature changed, omit this unit.
# ------------------------------------
# [Staff #1, Measure #49]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #50]
# Rest Chord Rest Rest Rest Rest Chord
# True, beatSum: 1.00000
# beatStr: 1.25,0;0.25,1;0.46875,0;
# ------------------------------------
# [Staff #1, Measure #51]
# Chord Rest Rest
# True, beatSum: 1.00
# beatStr: 1.25,0;0.25,1;0.46875,0;0.28125,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #52]
# Rest Rest Chord Chord Rest Chord
# True, beatSum: 1.0000
# beatStr: 1.25,0;0.25,1;0.46875,0;0.28125,1;1.125,0;0.1875,1;0.0625,0;0.375,1;
# ------------------------------------
# True, unitBeatSum: 4.00000
# ------------------------------------
# [Staff #1, Measure #53]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #1, Measure #54]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #1, Measure #55]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #1, Measure #56]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #1, Measure #57]
# Rest Rest Rest Chord Chord Chord Rest
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.3958333333333333333333333333,0;0.3541666666666666666666666667,1;0.25,0;
# ------------------------------------
# [Staff #1, Measure #58]
# Rest Rest Rest Rest Chord Chord Rest Rest Rest Rest
# True, beatSum: 1.0000000
# beatStr: 0.3958333333333333333333333333,0;0.3541666666666666666666666667,1;0.4609375,0;0.0156250,1;0.7734375,0;
# ------------------------------------
# [Staff #1, Measure #59]
# Rest
# True, beatSum: 1
# beatStr: 0.3958333333333333333333333333,0;0.3541666666666666666666666667,1;0.4609375,0;0.0156250,1;1.7734375,0;
# ------------------------------------
# [Staff #1, Measure #60]
# Rest Rest Rest Chord Rest Rest Rest Rest Rest Chord
# True, beatSum: 1.000000
# beatStr: 0.3958333333333333333333333333,0;0.3541666666666666666666666667,1;0.4609375,0;0.0156250,1;1.9765625,0;0.046875,1;0.71875,0;0.03125,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #61]
# Chord Rest Rest
# True, beatSum: 1.00
# beatStr: 0.25,1;0.75,0;
# ------------------------------------
# [Staff #1, Measure #62]
# Rest Rest Rest Rest Chord Chord Rest Rest Rest
# True, beatSum: 1.0000000
# beatStr: 0.25,1;0.9609375,0;0.0234375,1;0.765625,0;
# ------------------------------------
# [Staff #1, Measure #63]
# Rest
# True, beatSum: 1
# beatStr: 0.25,1;0.9609375,0;0.0234375,1;1.765625,0;
# ------------------------------------
# [Staff #1, Measure #64]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.25,1;0.9609375,0;0.0234375,1;1.765625,0;0.3333333333333333333333333333,1;0.1250000000000000000000000000,1;0.2083333333333333333333333334,1;0.1666666666666666666666666667,1;0.1666666666666666666666666667,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #65]
# Rest Chord Chord Chord Chord Rest
# True, beatSum: 1.000000000000000000000000000
# beatStr: 0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.750,1;0.125,0;
# ------------------------------------
# [Staff #1, Measure #66]
# Rest
# True, beatSum: 1
# beatStr: 0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.750,1;1.125,0;
# ------------------------------------
# [Staff #1, Measure #67]
# Rest
# True, beatSum: 1
# beatStr: 0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.750,1;2.125,0;
# ------------------------------------
# [Staff #1, Measure #68]
# Rest
# True, beatSum: 1
# beatStr: 0.04166666666666666666666666667,0;0.04166666666666666666666666667,1;0.04166666666666666666666666667,1;0.750,1;3.125,0;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #1, Measure #69]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# True, unitBeatSum: 1
# ------------------------------------
# [Staff #2, Measure #1]
# Rest Rest Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.875,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #2]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.875,0;0.0625,1;0.0625,1;0.125,1;0.25,1;0.625,1;
# ------------------------------------
# [Staff #2, Measure #3]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.875,0;0.0625,1;0.0625,1;0.125,1;0.25,1;0.625,1;0.1875,1;0.0625,1;0.125,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #4]
# Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.875,0;0.0625,1;0.0625,1;0.125,1;0.25,1;0.625,1;0.1875,1;0.0625,1;0.125,1;0.500,1;0.0625,1;0.0625,1;0.375,1;0.625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #5]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #6]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.5625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #7]
# Chord Chord Chord Chord Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.5625,1;0.0625,1;0.375,1;0.4375,1;0.0625,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #8]
# Chord Rest
# True, beatSum: 1.0
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.5625,1;0.0625,1;0.375,1;0.4375,1;0.0625,0;0.0625,1;0.0625,1;0.5,1;0.5,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #9]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #10]
# Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.625,1;
# ------------------------------------
# [Staff #2, Measure #11]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.625,1;0.375,1;0.375,1;0.25,1;
# ------------------------------------
# [Staff #2, Measure #12]
# Chord Chord Chord Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.625,1;0.375,1;0.375,1;0.25,1;0.375,1;0.500,1;0.0625,0;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #13]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #14]
# Chord Rest Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #15]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #16]
# Chord Chord Chord Chord Chord Rest Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,0;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #17]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #18]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #19]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #20]
# Chord Chord Chord Chord Chord
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.5,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #2, Measure #21]
# Chord Chord Chord Chord Rest Rest Chord Chord Chord
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.5,1;0.2500000000000000000000000000,1;0.07142857142857142857142857144,0;0.03571428571428571428571428572,1;0.07142857142857142857142857144,1;0.07142857142857142857142857144,1;
# ------------------------------------
# [Staff #2, Measure #22]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5,1;0.2500000000000000000000000000,1;0.07142857142857142857142857144,0;0.03571428571428571428571428572,1;0.07142857142857142857142857144,1;0.07142857142857142857142857144,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #23]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5,1;0.2500000000000000000000000000,1;0.07142857142857142857142857144,0;0.03571428571428571428571428572,1;0.07142857142857142857142857144,1;0.07142857142857142857142857144,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.5625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #24]
# Chord Chord Chord Chord Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5,1;0.2500000000000000000000000000,1;0.07142857142857142857142857144,0;0.03571428571428571428571428572,1;0.07142857142857142857142857144,1;0.07142857142857142857142857144,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.5625,1;0.0625,1;0.375,1;0.4375,1;0.0625,0;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #2, Measure #25]
# Chord Rest
# True, beatSum: 1.0
# beatStr: 0.5,1;0.5,0;
# ------------------------------------
# [Staff #2, Measure #26]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.5,1;0.5,0;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #27]
# Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.5,0;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.625,1;
# ------------------------------------
# [Staff #2, Measure #28]
# Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.5,1;0.5,0;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.625,1;0.375,1;0.375,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #29]
# Chord Chord Chord Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.500,1;0.0625,0;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #30]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.500,1;0.0625,0;0.0625,1;0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #31]
# Chord Rest Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.500,1;0.0625,0;0.0625,1;0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #32]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.500,1;0.0625,0;0.0625,1;0.375,1;0.375,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #33]
# Chord Chord Chord Chord Chord Rest Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,0;
# ------------------------------------
# [Staff #2, Measure #34]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,0;0.500,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #35]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,0;0.500,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #36]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,0;0.500,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;0.375,1;0.4375,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #37]
# Chord Chord Chord Chord Chord
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.5,1;
# ------------------------------------
# [Staff #2, Measure #38]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.5,1;0.5,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #39]
# Chord Rest Chord Chord Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.5,1;0.5,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,0;0.0625,1;0.25,1;0.125,0;0.125,1;
# ------------------------------------
# [Staff #2, Measure #40]
# Chord Chord Chord Rest Chord
# True, beatSum: 1.000
# beatStr: 0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.5,1;0.5,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.0625,0;0.0625,1;0.25,1;0.125,0;0.125,1;0.375,1;0.125,1;0.25,1;0.125,0;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #2, Measure #41]
# Chord Chord Chord Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.3125,1;0.0625,0;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #2, Measure #42]
# Chord Chord Chord Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.3125,1;0.0625,0;0.0625,1;0.0625,1;0.125,1;0.375,1;0.125,1;0.25,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #43]
# Chord Rest Chord Chord Rest Rest Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.3125,1;0.0625,0;0.0625,1;0.0625,1;0.125,1;0.375,1;0.125,1;0.25,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.1875,1;0.1250,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #44]
# Chord Rest Chord Chord Rest Rest Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.3125,1;0.0625,0;0.0625,1;0.0625,1;0.125,1;0.375,1;0.125,1;0.25,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.1875,1;0.1250,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.125,0;0.1875,1;0.3125,0;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #45]
# Chord Rest Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.500,1;0.125,0;
# ------------------------------------
# [Staff #2, Measure #46]
# Chord Chord Chord Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.500,1;0.125,0;0.375,1;0.125,1;0.25,1;0.125,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #47]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,1;0.125,0;0.500,1;0.125,0;0.375,1;0.125,1;0.25,1;0.125,0;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #2, Measure #48]
# Time Signature changed, omit this unit.
# ------------------------------------
# [Staff #2, Measure #49]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #50]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #51]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #52]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #53]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #54]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #55]
# Chord Chord Chord Chord Rest Rest Chord
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.375,0;
# ------------------------------------
# [Staff #2, Measure #56]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3333333333333333333333333333,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.375,0;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #2, Measure #57]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #58]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #59]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #60]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,1;0.0625,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #61]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;
# ------------------------------------
# [Staff #2, Measure #62]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #2, Measure #63]
# Rest Rest Chord Rest
# True, beatSum: 1.0000
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,0;0.1875,1;0.5,0;
# ------------------------------------
# [Staff #2, Measure #64]
# Rest
# True, beatSum: 1
# beatStr: 0.375,1;0.0625,1;0.0625,1;0.375,1;0.500,1;0.500,1;0.0625,1;0.0625,1;0.3125,0;0.1875,1;1.5,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #2, Measure #65]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #2, Measure #66]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #2, Measure #67]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #2, Measure #68]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #2, Measure #69]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# True, unitBeatSum: 1
# ------------------------------------
# [Staff #3, Measure #1]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #3, Measure #2]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 1,0;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #3]
# Chord Rest Chord Chord Rest Rest Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 1,0;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.1875,1;0.3125,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #4]
# Chord Chord Chord Chord Chord Rest Rest Rest
# True, beatSum: 1.0000
# beatStr: 1,0;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.1875,1;0.3125,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.1875,1;0.4375,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #5]
# Chord Rest Chord Chord Rest Rest Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #6]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #7]
# Chord Rest Chord Chord Rest Rest Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #8]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.1875,1;0.2500,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #9]
# Chord Rest Chord Rest Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.125,1;0.375,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #10]
# Chord Chord Chord Chord Chord Rest Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.125,1;0.375,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.1875,1;0.4375,0;
# ------------------------------------
# [Staff #3, Measure #11]
# Chord Rest Chord Rest Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.125,1;0.375,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.1875,1;0.4375,0;0.25,1;0.125,0;0.125,1;0.25,0;0.25,1;
# ------------------------------------
# [Staff #3, Measure #12]
# Chord Rest Chord Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.125,1;0.375,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.1875,1;0.4375,0;0.25,1;0.125,0;0.125,1;0.25,0;0.25,1;0.25,1;0.125,0;0.3125,1;0.3125,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #13]
# Chord Rest Chord Chord Rest Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.4375,0;
# ------------------------------------
# [Staff #3, Measure #14]
# Chord Rest Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.4375,0;0.25,1;0.25,0;0.25,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #15]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.4375,0;0.25,1;0.25,0;0.25,1;0.125,1;0.250,1;0.0625,1;0.0625,1;0.125,1;0.1875,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #16]
# Chord Chord Chord Chord Rest Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.1875,1;0.4375,0;0.25,1;0.25,0;0.25,1;0.125,1;0.250,1;0.0625,1;0.0625,1;0.125,1;0.1875,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.1875,1;0.1875,1;0.250,0;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #17]
# Chord Chord Chord Chord Chord Rest Chord Chord Chord Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #18]
# Chord Chord Chord Chord Rest Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.1875,1;0.1875,1;0.250,0;
# ------------------------------------
# [Staff #3, Measure #19]
# Chord Chord Chord Chord Chord Rest Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.1875,1;0.1875,1;0.250,0;0.250,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,0;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #20]
# Chord Chord Rest Rest Chord Chord Rest Rest Chord Chord Rest Chord Chord Chord Rest Chord
# True, beatSum: 0.9999999999999999999999999999
# beatStr: 0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.1875,1;0.1875,1;0.250,0;0.250,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,0;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.03125,1;0.0234375,0;0.0234375,1;0.046875,0;0.08333333333333333333333333334,1;0.08333333333333333333333333334,1;0.08333333333333333333333333334,0;0.0625,1;0.0625,1;0.125,1;0.125,0;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.000000000000000000000000000
# ------------------------------------
# [Staff #3, Measure #21]
# Chord Rest Chord Chord Chord Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,0;0.1875,1;0.1875,1;0.0625,1;0.125,0;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #22]
# Chord Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,0;0.1875,1;0.1875,1;0.0625,1;0.125,0;0.0625,1;0.0625,1;0.75,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #23]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.25,1;0.0625,0;0.1875,1;0.1875,1;0.0625,1;0.125,0;0.0625,1;0.0625,1;0.75,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #24]
# Chord Rest Chord Chord Rest Rest Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,0;0.1875,1;0.1875,1;0.0625,1;0.125,0;0.0625,1;0.0625,1;0.75,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.1875,1;0.3125,0;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #25]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #26]
# Chord Rest Chord Rest Rest Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.125,1;0.3125,0;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #27]
# Chord Chord Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.125,1;0.3125,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #28]
# Chord Rest Chord Rest Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.125,1;0.3125,0;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.5,0;0.25,1;0.125,0;0.125,1;0.25,0;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #29]
# Chord Rest Chord Chord Rest
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.375,1;0.25,0;
# ------------------------------------
# [Staff #3, Measure #30]
# Chord Rest Chord Chord Rest Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.375,1;0.25,0;0.25,1;0.125,0;0.1875,1;0.4375,0;
# ------------------------------------
# [Staff #3, Measure #31]
# Chord Rest Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.375,1;0.25,0;0.25,1;0.125,0;0.1875,1;0.4375,0;0.25,1;0.25,0;0.1875,1;0.0625,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #32]
# Rest Chord Chord Chord Chord Rest Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.375,1;0.25,0;0.25,1;0.125,0;0.1875,1;0.4375,0;0.25,1;0.25,0;0.1875,1;0.0625,1;0.125,1;0.125,1;0.125,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #33]
# Chord Rest Rest Chord Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.1875,0;0.1875,1;0.375,0;
# ------------------------------------
# [Staff #3, Measure #34]
# Rest Rest Chord Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.1875,0;0.1875,1;0.9375,0;0.1875,1;0.25,0;
# ------------------------------------
# [Staff #3, Measure #35]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.1875,0;0.1875,1;0.9375,0;0.1875,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #36]
# Chord Chord Chord Chord Chord Rest Chord Chord Chord Rest Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.1875,0;0.1875,1;0.9375,0;0.1875,1;0.25,0;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.250,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.0625,1;0.0625,1;0.0625,0;0.1875,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #37]
# Rest Chord Rest
# True, beatSum: 1.00
# beatStr: 0.25,0;0.25,1;0.5,0;
# ------------------------------------
# [Staff #3, Measure #38]
# Chord Chord Chord Chord Chord Chord Rest Rest
# True, beatSum: 1.0000
# beatStr: 0.25,0;0.25,1;0.5,0;0.3125,1;0.1875,1;0.1875,1;0.1250,1;0.1875,0;
# ------------------------------------
# [Staff #3, Measure #39]
# Chord Rest
# True, beatSum: 1.00
# beatStr: 0.25,0;0.25,1;0.5,0;0.3125,1;0.1875,1;0.1875,1;0.1250,1;0.1875,0;0.75,1;0.25,0;
# ------------------------------------
# [Staff #3, Measure #40]
# Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,0;0.25,1;0.5,0;0.3125,1;0.1875,1;0.1875,1;0.1250,1;0.1875,0;0.75,1;0.25,0;0.5,1;0.25,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #41]
# Chord Rest Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.125,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #3, Measure #42]
# Chord Rest Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,0;0.125,1;0.25,1;0.25,1;0.25,1;0.125,0;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #43]
# Chord Rest Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.125,1;0.25,1;0.25,1;0.25,1;0.125,0;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #3, Measure #44]
# Chord Rest Chord Chord Rest Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,0;0.125,1;0.25,1;0.25,1;0.25,1;0.125,0;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.0625,0;0.1875,1;0.125,1;0.125,1;0.25,1;0.25,1;0.125,0;0.125,1;0.25,1;0.125,0;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #45]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.5000,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #46]
# Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.5000,1;0.125,1;0.5,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #3, Measure #47]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.1875,1;0.0625,1;0.125,1;0.5000,1;0.125,1;0.5,1;0.25,1;0.25,1;0.375,1;0.0625,1;0.0625,1;0.250,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #48]
# Time Signature changed, omit this unit.
# ------------------------------------
# [Staff #3, Measure #49]
# Chord Rest Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.25,0;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #50]
# Rest Chord Chord Chord Chord Rest Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,0;0.25,1;0.125,1;0.125,1;0.125,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #3, Measure #51]
# Rest
# True, beatSum: 1
# beatStr: 0.25,1;0.25,0;0.25,1;0.125,1;0.125,1;0.125,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;1,0;
# ------------------------------------
# [Staff #3, Measure #52]
# Rest Rest Chord Chord Rest Chord Rest
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,0;0.25,1;0.125,1;0.125,1;0.125,0;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,0;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;1.1875,0;0.1250,1;0.0625,0;0.125,1;0.5,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #3, Measure #53]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #3, Measure #54]
# Chord Chord Chord Chord Chord Rest Chord Chord Chord Rest Chord Chord Chord
# True, beatSum: 1.0000
# ...
# ------------------------------------
# [Staff #6, Measure #15]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,0;0.25,1;0.25,0;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #16]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,0;0.25,1;0.25,0;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #17]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #18]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #19]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #20]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #21]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #22]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #23]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #24]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #25]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #26]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #27]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #28]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #29]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #30]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #31]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #32]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #33]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #34]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #35]
# Chord Chord Chord Chord
# True, beatSum: 1.00
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;
# ------------------------------------
# [Staff #6, Measure #36]
# Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.0625,1;0.0625,1;0.125,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.25,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #37]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #38]
# Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #39]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.1875,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #40]
# Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.125,1;0.25,1;0.25,1;0.1875,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.25,1;0.25,1;0.25,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #41]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #42]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #43]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #44]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.25,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #45]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #46]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #47]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #48]
# Time Signature changed, omit this unit.
# ------------------------------------
# [Staff #6, Measure #49]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #50]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #51]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #52]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.25,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #53]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #54]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #55]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #56]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #57]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #58]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #59]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #60]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #61]
# Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;
# ------------------------------------
# [Staff #6, Measure #62]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #63]
# Chord Chord Chord Chord Chord Chord Chord Chord Chord
# True, beatSum: 1.0000
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;
# ------------------------------------
# [Staff #6, Measure #64]
# Rest
# True, beatSum: 1
# beatStr: 0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;0.0625,1;0.0625,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.125,1;0.0625,1;0.0625,1;1,0;
# ------------------------------------
# True, unitBeatSum: 4.0000
# ------------------------------------
# [Staff #6, Measure #65]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# [Staff #6, Measure #66]
# Rest
# True, beatSum: 1
# beatStr: 2,0;
# ------------------------------------
# [Staff #6, Measure #67]
# Rest
# True, beatSum: 1
# beatStr: 3,0;
# ------------------------------------
# [Staff #6, Measure #68]
# Rest
# True, beatSum: 1
# beatStr: 4,0;
# ------------------------------------
# True, unitBeatSum: 4
# ------------------------------------
# [Staff #6, Measure #69]
# Rest
# True, beatSum: 1
# beatStr: 1,0;
# ------------------------------------
# True, unitBeatSum: 1
# ------------------------------------

# %%
#Store data into MongoDB
client = MongoClient('mongodb://10.120.30.8:27017')
db = client['music']
collect = db['tempo_beats']
collect.insert_many(mainList2)
del mainList2[:]

# %%
#Query MongoDB
cur = collect.find({'staff_id':5},{'_id':0,'musicname':1,'beats':1})
for i, item in enumerate(cur):
    print i, item
    print '------------------------------------'
