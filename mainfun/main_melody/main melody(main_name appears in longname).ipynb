# %% [markdown]
# ## Determine main melody
#  - by score (author specified)
#  - pan (左右聲道平衡度)
#  - velociy (按鍵力道)
#  - 平均旋律
#  - 和弦所佔比率

# %%
main_name = ['melody','melodie','vocal','voice','sing','lead']
sub_name = ['drum']

# %% [markdown]
# ## pan value

# %%
def panDect(parts):
    pan = {}
    for part in parts:
        staffs = part.select('Staff')
        for staff in staffs:
            i = staff.get('id')
            channel = part.select('Channel')[0].select('controller')
            value = 0
            if len(channel) == 0 or len(channel.select('controller')) == 0 or channel.select('controller')[0].get('ctrl') != '10':
                value = 63
            else:
                value = channel.select('controller')[0].get('value')
            pan.update({i:value})
    return pan

# %% [markdown]
# ## average velocity

# %%
def velDect(addr,ids):
    fm = open(addr, 'r')
    music = fm.read()
    fm.close()
    vela = {}
    staffs = [staff for staff in bs(music,'xml').select('Score > Staff') if staff.get('id') in ids]
    for staff in staffs:
        vels = staff.select('Note velocity')
        n = len(vels)
        s = 0.0
        for vel in vels:
            v = int(vel.text)
            s += v
        avg = s/n
        vela.update({staff.get('id'):str(avg)})
    return vela

# %% [markdown]
# ## average pitch

# %%
import math
def pitDect(addr,ids):
    fm = open(addr, 'r')
    music = fm.read()
    fm.close()
    pits = {}
    dutype = {'whole':1.0,'half':1.0/2,'quarter':1.0/4,'eighth':1.0/8,'16th':1.0/16,'32nd':1.0/32,'64th':1.0/64,'128th':1.0/128}
    staffs = [staff for staff in bs(music,'xml').select('Score > Staff') if staff.get('id') in ids]
    for staff in staffs:
        pitch_sum = 0
        pitch_time = 0
        for measure in staff.select('Measure'):
            for chord in [c for c in list(measure.children) if c != '\n' and c.name == 'Chord']:
                max_pitch = max([int(d.pitch.text) for d in chord.select('Note')])
                dot = 0
                if len(chord.select('dot')) != 0:
                    dot = int(chord.select('dot')[0].text)
                dutime = dutype[chord.durationType.text] * (2-math.pow(1.0/2,dot))
                pitch_sum += max_pitch * dutime
                pitch_time += dutime
        avg_pich = pitch_sum/pitch_time
        pits.update({staff.get('id'):str(avg_pich)})
    return pits

# %% [markdown]
# ## chords' rate

# %%
def rateDect(addr,ids):
    fm = open(addr, 'r')
    music = fm.read()
    fm.close()
    rates = {}
    staffs = [staff for staff in bs(music,'xml').select('Score > Staff') if staff.get('id') in ids]
    for staff in staffs:
        num = 0
        n = 0
        for measure in staff.select('Measure'):
            chords = [c for c in list(measure.children) if c != '\n' and c.name == 'Chord']
            n += len(chords)
            for chord in chords:
                if len(chord.select('Note')) == 1:
                    num += 1
        rates.update({staff.get('id'):str(float(num)/n)})
    return rates

# %% [markdown]
# ## sound area

# %%
def areaDect(addr,ids):
    fm = open(addr, 'r')
    music = fm.read()
    fm.close()
    area = {}
    staffs = [staff for staff in bs(music,'xml').select('Score > Staff') if staff.get('id') in ids]
    dutype = {'whole':1.0,'half':1.0/2,'quarter':1.0/4,'eighth':1.0/8,'16th':1.0/16,'32nd':1.0/32,'64th':1.0/64,'128th':1.0/128}
    for staff in staffs:
        du = 0
        all_du = []
        for measure in staff.select('Measure'):
            chords = [c for c in list(measure.children) if c != '\n' and c.name == 'Chord']
            for chord in chords:
                all_du.append(dutype[chord.durationType.text])
        area.update({staff.get('id'):str(sum(all_du))})
    return area

# %% [markdown]
# ## determine main melodies

# %%
import pandas as pd
def detMain(data):
    form = pd.DataFrame(data).transpose()
    form.columns = ['pan','vel_rate','pit_rate','cho_rate','area','ismaster1']
    # need to add...
    return form

# %% [markdown]
# ### isMaster:判斷LONGNAME裡是否有main_name的字，有給1沒有給0

# %%
#isMaster
def isMaster(parts):#這裡的parts是main function裡的cand
    ismaster = {}
    for part in parts:
        staffs = part.select('Staff')#找每個樂器裡面的Staff
        for staff in staffs:
            i = staff.get('id') 
            value=0#value先給值:0
            pname = part.select('longName')[0].text.encode('utf8').lower()            
            if len([word for word in main_name if word in pname]) != 0: # instru. name
                value=1#如果pname裡面有main_name的字，value改給值:1
            ismaster.update({i:value})
    return ismaster

# %% [markdown]
# ## main function

# %%
#版本1用isMaster找出LONGNAME裡面有在字典MAIN_NAME的給1沒有的給0
from bs4 import BeautifulSoup as bs
# addr = 'E:/musicteam/music/Believe.mscx'
addr = 'E:/musicteam/music/Again.mscx'
fm = open(addr, 'r')
music = fm.read()
fm.close()
cand = bs(music,'xml').select('Part')
main_cand = []
sub_cand = []
for s in [par for par in cand if len(par.select('longName')) != 0]:
    pname = s.select('longName')[0].text.encode('utf8').lower()
    if len([word for word in main_name if word in pname]) != 0: # instru. name
        main_cand.append(s)        
#         cand.remove(s)
    if len([word for word in sub_name if word in pname]) != 0:
        sub_cand.append(s)
        cand.remove(s)
    for cin in [c for c in list(s.select('Instrument')[0].children) if c != '\n']: # more than one instru. in this staff
        if cin.get('pitch') is not None:
            if s in cand:
                sub_cand.append(s)
                cand.remove(s)
            break
mesg = {}
ismaster = isMaster(cand)
pan = panDect(cand)
ids = pan.keys()
vels = velDect(addr,ids)
pits = pitDect(addr,ids)
rates = rateDect(addr,ids)
area = areaDect(addr,ids)
#print pan.keys(), area.keys(),ismaster1.keys(),ismaster1
#print len(pan),len(vels),len(pits),len(rates),len(area),len(ismaster1)
[mesg.update({a:[pan[a],vels[a],pits[a],rates[a],area[a],ismaster[a]]}) for a in pan.keys()]
f = detMain(mesg)
print f
# Out:
# [u'11', u'10', u'13', u'12', u'14', u'1', u'3', u'2', u'5', u'7', u'6', u'9', u'8'] [u'11', u'10', u'13', u'12', u'14', u'1', u'3', u'2', u'5', u'7', u'6', u'9', u'8'] [u'1', u'3', u'5', u'4', u'7', u'6', u'9', u'8'] {u'1': 1, u'3': 0, u'5': 0, u'4': 0, u'7': 0, u'6': 0, u'9': 1, u'8': 0}
# 13 13 13 13 13 8
#    pan       vel_rate       pit_rate        cho_rate       area ismaster1
# 1   63  101.384615385  64.6890418818             0.7   54.46875         0
# 10  63  70.7823834197  56.4756918474   0.85119047619    83.5625         0
# 11  63  103.706231454  63.2879455346  0.994029850746  39.015625         1
# 12  63           65.6           63.8            0.75       6.25         0
# 13  63           74.4          42.75  0.636363636364        8.0         0
# 14  63   75.914893617  71.1922428331             1.0   18.53125         0
# 2   63  98.2965779468  50.6162162162  0.768115942029    57.8125         0
# 3   63   76.795379538  73.0679811049  0.616504854369  76.078125         0
# 5   63  89.0588235294   58.696969697             1.0     2.0625         0
# 6   63  89.3536585366  73.4091627172             1.0   19.78125         0
# 7   63          103.0         76.125             1.0        1.0         0
# 8   63  82.6707317073  56.6442307692  0.828571428571       58.5         0
# 9   63  66.1096774194  61.9502074689  0.959731543624    75.3125         0

# %% [markdown]
# ### main function2 最後決定用這個跑測試資料的CSV

# %%
#版本2與版本1一樣，不同於沒用isMaster
from bs4 import BeautifulSoup as bs
import os

fi = open('E:/musicteam/musictxt/test2.csv','w')
for filename in os.listdir('E:/musicteam/music'):
    try:
        addr = 'E:/musicteam/music/'+filename
        fm = open(addr, 'r')
        music = fm.read()
        fm.close()
        cand = bs(music,'xml').select('Part')
        main_cand = []
        sub_cand = []
        ismaster = {}
        for s in [par for par in cand if len(par.select('longName')) != 0]:
            pname = s.select('longName')[0].text.encode('utf8').lower()
            for staff in s.select('Staff'):
                i = staff.get('id') 
                value=0
                if len([word for word in main_name if word in pname]) != 0: # instru. name
                    main_cand.append(s)
                    value=1
                ismaster.update({i:value})
        #             cand.remove(s)
            if len([word for word in sub_name if word in pname]) != 0:
                sub_cand.append(s)
                cand.remove(s)
            for cin in [c for c in list(s.select('Instrument')[0].children) if c != '\n']: # more than one instru. in this staff
                if cin.get('pitch') is not None:
                    if s in cand:
                        sub_cand.append(s)
                        cand.remove(s)
                    break
        mesg = {}
        pan = panDect(cand)
        ids = pan.keys()
        vels = velDect(addr,ids)
        pits = pitDect(addr,ids)
        rates = rateDect(addr,ids)
        area = areaDect(addr,ids)
        # print pan.keys(), area.keys(),ismaster1.keys(),ismaster1
        # print len(pan),len(vels),len(pits),len(rates),len(area),len(ismaster1)
        [mesg.update({a:[pan[a],vels[a],pits[a],rates[a],area[a],ismaster[a]]}) for a in pan.keys()]
    #   f = detMain(mesg)
        # print f
        #以下為判斷LONGNAME裡有main_name的歌寫到CSV
        if len([dd for dd in sorted(pan.keys()) if ismaster[dd]==1]) != 0:        
            for a in sorted([int(x) for x in mesg.keys()]):
                a=str(a)
                for b in range(len(mesg[a])):
                    fi.write(str(mesg[a][b])+',')
                fi.write('\n')
            fi.write('\n')
            print 'write:'+filename.decode('big5')
    except:
        print filename+',error'
fi.close()
# Out:
# write:16.mscx
# write:2 Become 1.mscx
# write:3 AM.mscx
# write:409 In Your Coffeemaker.mscx
# write:500 Miles.mscx
# write:7 Things.mscx
# write:A Lovers Concerto.mscx
# write:A Song For You.mscx
# write:A Warm Place.mscx
# write:Adia.mscx
# write:Afternoon Delight.mscx
# write:Again.mscx
# write:All I Ever Need Is You.mscx
# write:All I Have to Do Is Dream.mscx
# write:All Night Long.mscx
# write:All That She Wants.mscx
# write:Always Be My Baby.mscx
# write:Always on my mind.mscx
# write:Always somewhere.mscx
# write:Always.mscx
# write:America.mscx
# write:American Idiot.mscx
# write:American Pie.mscx
# write:Amish Paradise.mscx
# write:And I love you so.mscx
# write:And Then He Kissed Me.mscx
# write:And When I Die.mscx
# write:Angels.mscx
# write:Annies Song.mscx
# write:Any Time You Need A Friend.mscx
# write:Are you lonesome tonight.mscx
# write:Armitage Shanks.mscx
# write:Arthurs Theme.mscx
# write:As Long As You Love Me.mscx
# write:At last.mscx
# write:At Your Side.mscx
# Ave Maria.mscx,error
# write:Baby Boy feat Sean Paul.mscx
# Baby feat Ludacris.mscx,error
# write:Back 2 Good.mscx
# write:Back Here.mscx
# write:Bad Medicine.mscx
# write:Bad.mscx
# write:Beautiful Dirty Rich.mscx
# write:Beautiful Noise.mscx
# write:Beautiful sunday.mscx
# write:Beautiful, Dirty, Rich.mscx
# write:Bed Of Roses.mscx
# write:Bent.mscx
# write:Bertie Higgins.mscx
# write:Billie Jean.mscx
# write:Billy Jean.mscx
# write:Birds and bees.mscx
# write:Birds and the bees.mscx
# write:Black Or White.mscx
# write:Bliss.mscx
# write:Blowing in the wind.mscx
# write:Blowing kisses in the wind.mscx
# write:Born This Way.mscx
# write:Born to Make You Happy.mscx
# write:Brat.mscx
# write:Breaking the Habit.mscx
# write:Breakout.mscx
# write:Burning in the Skies.mscx
# write:By the time I get to phoenix.mscx
# write:Bye by love.mscx
# write:Bye Bye Bye.mscx
# write:Bye bye love.mscx
# write:Can You Feel The Love Tonight.mscx
# write:Candle In The Wind.mscx
# write:Cathys Clown.mscx
# write:Chicago.mscx
# write:Christie Road.mscx
# write:Church of the Poison Mind.mscx
# write:Civil War.mscx
# write:Cleanin’ Out My Closet.mscx
# write:Close to You.mscx
# write:Closer.mscx
# write:Color My World.mscx
# write:Come Back To Me.mscx
# write:Come What May.mscx
# write:Coming Clean.mscx
# write:Cool Jerk.mscx
# write:Copacabana.mscx
# write:Count On Me.mscx
# write:Crazy For You.mscx
# write:Cruel Summer.mscx
# write:Dare to Be Stupid.mscx
# write:Day by Day.mscx
# write:Daydream Believer.mscx
# write:Delilah.mscx
# write:Diana.mscx
# write:Disco Heaven.mscx
# write:Disturbia.mscx
# write:Do Da Da.mscx
# write:Do That To Me One More Time.mscx
# write:Do You Know the Way to San Jose.mscx
# write:Do You Really Want to Hurt Me.mscx
# write:Does Anybody Really Know.mscx
# write:Dominated Love Slave.mscx
# write:Don't You Cry No More.mscx
# write:Dont Let Me Be the Last to Know.mscx
# write:Dont Say You Love Me.mscx
# write:Dont Turn Around.mscx
# write:Dream A Little Dream of Me.mscx
# write:Dream.mscx
# write:Dreaming of You.mscx
# write:Dust in the Wind.mscx
# write:E.T..mscx
# write:Easier to Run.mscx
# write:Eh Eh Nothing Else I Can Say.mscx
# write:Eh, Eh (Nothing Else I Can Say).mscx
# write:Emenius Sleepus.mscx
# write:End of the world.mscx
# write:Endless Love.mscx
# write:Enter tainer.mscx
# write:Escapade.mscx
# write:Escape The Pina Colada Song.mscx
# write:ET.mscx
# write:Even The Nights Are Better.mscx
# write:Every Time You Go Away.mscx
# write:Everybody.mscx
# write:Faith.mscx
# write:Fashion.mscx
# write:Father Figure.mscx
# write:Feelin Groovy.mscx
# write:Feeling So Good.mscx
# write:Feeling Stronger Every Day.mscx
# write:Feelings.mscx
# write:Food Around The Corner.mscx
# write:Fool Again.mscx
# write:Foolish Beat.mscx
# write:Foolish Games.mscx
# write:For All We Know.mscx
# write:Forgiven Not Forgotten.mscx
# write:Free your mind.mscx
# From the Bottom of My Broken Heart.mscx,error
# write:From the Inside.mscx
# write:Fun fun fun.mscx
# write:Geek Stink Breath.mscx
# write:Genie in a bottle.mscx
# write:Give Me One Reason.mscx
# write:Good bye to romance.mscx
# write:Good Morning Starshine.mscx
# write:Goodbye to Love.mscx
# write:Goonies R Good Enough.mscx
# write:Green Day.mscx
# write:Green Grass of Home.mscx
# write:Groovy Kind Of Love.mscx
# write:Guilty Conscience.mscx
# write:Gypsies Tramps  Thieves.mscx
# write:Half a Chance.mscx
# write:Halo.mscx
# write:Happy Together.mscx
# write:Have I told you.mscx
# write:Have You Ever Been Mellow.mscx
# write:Have Yourself a Merry Little Christmas.mscx
# write:Having A Blast.mscx
# write:Head Like A Hole.mscx
# write:Headline News.mscx
# write:Heal The World.mscx
# write:Heaven Is a Place on Earth.mscx
# write:Heaven Knows.mscx
# write:Heaven.mscx
# write:Hello.mscx
# write:Here We Go.mscx
# write:Hes A Rebel.mscx
# write:Hold My Hand.mscx
# write:Holiday.mscx
# Home.mscx,error
# write:Hooked on a Feeling.mscx
# write:How Deep Is Your Lov.mscx
# write:I Cant Get Enough Of You.mscx
# write:I Cant Quit Her.mscx
# write:I Drive Myself Crazy.mscx
# write:I Drove All Night.mscx
# write:I Got You Babe.mscx
# write:I Have Nothing At All.mscx
# write:I Honestly Love You.mscx
# write:I Just Can't Stop Loving You.mscx
# write:I Knew You Were Trouble.mscx
# write:I Know My Love.mscx
# write:I left my heart in Sanfrancisco.mscx
# write:I Need to Know.mscx
# write:I Never Loved You Anyway.mscx
# write:I Say A Little Prayer.mscx
# write:I Want It That Way.mscx
# write:I Want To Be Alone.mscx
# write:I'll Remember.mscx
# write:Id Like to Teach the World to Sing.mscx
# write:If I Never See Your Face Again.mscx
# write:If It Makes You Happy.mscx
# write:If You Leave Me Now.mscx
# write:Ill Be There.mscx
# write:Ill Never Break Your Heart.mscx
# write:Ill Never Fall in Love Again.mscx
# write:Ill Never Love This Way Again.mscx
# write:Im Every Woman.mscx
# write:Im Not Your Stepping Stone.mscx
# write:In The End.mscx
# write:Inside Out.mscx
# write:Intimacy.mscx
# write:It's alright.mscx
# write:Its Not Unusual.mscx
# write:Jaded.mscx
# write:Jesus Christ Superstar.mscx
# write:Judas.mscx
# write:Just Dance.mscx
# write:Just Help Yourself.mscx
# write:Just Like A Pill.mscx
# write:Keep The Faith.mscx
# write:King For A Day.mscx
# write:Knock Three Times.mscx
# write:Knowledge.mscx
# write:Kodachrome.mscx
# write:l Final Countdown.mscx
# write:Larger Than Life.mscx
# write:Last Stop This Town.mscx
# write:Last Train To Clarkesville.mscx
# write:Last.mscx
# write:Lay Down.mscx
# write:Leave Me Alone (I’m Lonely).mscx
# write:Leave Me Alone Im Lonely.mscx
# write:Leave Me Alone.mscx
# write:Lemon Tree.mscx
# write:Let Me Be There.mscx
# write:Like I Love You.mscx
# write:Linger.mscx
# write:Listen.mscx
# write:Live To Tell.mscx
# write:Living On A Prayer.mscx
# write:Lollipop Candy Man.mscx
# write:Love Gives Love Takes.mscx
# write:Love Is All.mscx
# write:Love me tender.mscx
# write:Love to Love You.mscx
# write:Loving you.mscx
# write:Lucky.mscx
# write:Making Love Out Of Nothing.mscx
# write:Mandy.mscx
# write:Mayday.mscx
# write:Me and Julio Down by the Schoolyard.mscx
# write:Me Myself and I.mscx
# write:Meet the Flintstones.mscx
# write:Merry Christmas Darling.mscx
# write:Millenium.mscx
# write:Misty.mscx
# write:Mockingbird.mscx
# write:Monster.mscx
# write:More than I can say.mscx
# write:Murder was the case.mscx
# write:My December.mscx
# write:My Heart Stays With You.mscx
# write:My Love Is Your Love.mscx
# write:Naked.mscx
# write:Naver fall in love again.mscx
# write:Never Forget You.mscx
# write:Never My Love.mscx
# write:Never Say Goodbye.mscx
# write:No One Else Comes Close.mscx
# write:No One Knows.mscx
# write:Nobody Does it Better.mscx
# write:Now And Forever.mscx
# write:Numb.mscx
# write:One More Try.mscx
# write:One Step Closer.mscx
# write:One Sweet Day.mscx
# write:Orinoco Flow.mscx
# write:Our Song.mscx
# write:Paper Lanterns.mscx
# write:Perhaps love.mscx
# write:Phantom of the Opera.mscx
# write:Physical.mscx
# write:Pigeons and Crumbs.mscx
# write:Platypus I Hate You.mscx
# write:Pleasant Valley Sunday.mscx
# write:Please Mr Please.mscx
# write:Please please me.mscx
# write:Polly.mscx
# write:Pride (In The Name Of Love).mscx
# write:Puke.mscx
# write:Pulling Teeth.mscx
# write:Puppy Love.mscx
# write:Push.mscx
# write:Queen of Hollywood.mscx
# write:Quit Playing Games With My Heart.mscx
# write:Radio.mscx
# write:Rain drop keep falling on my head.mscx
# write:Rainy Day.mscx
# write:Rape Me.mscx
# write:Reach.mscx
# write:Red.mscx
# write:Remember.mscx
# write:Rest.mscx
# write:Rhythm of the rain.mscx
# write:Ride Like the Wind.mscx
# write:Right Here Waiting.mscx
# write:Right Time.mscx
# write:Rock Me Amadeus.mscx
# write:Rock Your Body.mscx
# write:Run away.mscx
# write:Rush Rush.mscx
# write:Russian Roulette.mscx
# write:Sailing.mscx
# write:Sanctified.mscx
# write:SanFrancisco.mscx
# write:Sassafras Roots.mscx
# write:Saturday in the Park.mscx
# write:Save The Best For Last.mscx
# write:Saving All My Love For You.mscx
# write:Say Youll Be There.mscx
# write:Sealed with kiss.mscx
# write:Season in the sun.mscx
# write:Seasons in the sun.mscx
# write:Second Time Around.mscx
# write:Secret Life.mscx
# write:Set Fire To The Rain.mscx
# write:Sexy Bitch feat. Akon.mscx
# write:Shape of My Heart.mscx
# write:She love you.mscx
# write:She Never Heard Me Call.mscx
# She.mscx,error
# write:Shes The One.mscx
# write:Shock!.mscx
# write:Shoop Shoop Song.mscx
# write:Show Me the Meaning.mscx
# write:Silver threads and golden needles.mscx
# write:Sing.mscx
# write:Single Ladies Put A Ring On It.mscx
# write:Skyfall.mscx
# write:Slip Sliding Away.mscx
# write:Smoke gets in you eyes.mscx
# write:Smoke gets in your eyes.mscx
# write:Smooth Criminal.mscx
# write:Snowbird.mscx
# write:So Young.mscx
# write:Sober.mscx
# write:Some wheremy love.mscx
# write:Someday.mscx
# write:Something.mscx
# write:Sometimes.mscx
# write:Somewhere I Belong.mscx
# write:Sounds of Silence.mscx
# write:Speechless.mscx
# write:Spinning Wheel.mscx
# write:Spudscum.mscx
# write:Steal My Sunshine.mscx
# write:Step by Step.mscx
# write:Still Got The Blues.mscx
# write:Strange Currencies.mscx
# write:Stranger In Moscow.mscx
# write:Strong Enough.mscx
# write:Stuck On You.mscx
# write:Sugar sugar.mscx
# write:Sukiyaki.mscx
# write:Sussudio.mscx
# write:Sweet Child O'Mine.mscx
# write:Take Back.mscx
# write:Take Me Home Country Road.mscx
# write:Take Me Home Country Roads.mscx
# write:Take On Me.mscx
# write:Telephone.mscx
# write:Thats the Way Ive Always Heard It Should Be.mscx
# write:The Fame.mscx
# write:The Fonz.mscx
# write:The Grouch.mscx
# write:The Itch.mscx
# write:The Little Things Give You Away.mscx
# write:The Lonely Bull.mscx
# write:The Messenger.mscx
# write:The One That Got Away.mscx
# write:The One You Love.mscx
# write:The Right Time.mscx
# write:The Way I Want To Touch You.mscx
# write:The Wind Beneath My Wings.mscx
# write:Theme from a Summer Place.mscx
# write:There Must Be An Angel.mscx
# write:They Dont Know.mscx
# write:Thinking Of You.mscx
# write:This I Promise You.mscx
# write:This Masquerade.mscx
# write:Three Times A Lady.mscx
# write:Tie a yellow ribbon.mscx
# write:Tight Wad Hill.mscx
# write:Titanium feat Sia.mscx
# write:Titanium feat. Sia.mscx
# write:To Love Somebody.mscx
# write:To Sir with love.mscx
# write:Too Much.mscx
# write:Top of world.mscx
# write:Total Eclipse of the Heart.mscx
# write:True Colors.mscx
# write:True.mscx
# write:Tubthumping.mscx
# write:Turn Me On feat. Nicki Minaj.mscx
# write:Two Hearts.mscx
# write:Umbrella feat JayZ.mscx
# write:Umbrella feat. Jay-Z.mscx
# write:Under the board walk.mscx
# write:Ur So Gay.mscx
# write:Vacation.mscx
# write:Venus.mscx
# write:Verse-Chorus-Verse.mscx
# write:Vincent.mscx
# write:Virytual insanit.mscx
# write:Vision Of Love.mscx
# write:Waiting For Tonight.mscx
# write:Walk On By.mscx
# write:Walking Contradiction.mscx
# write:Walking On The Sun.mscx
# write:We Are Never Ever Getting Back Together.mscx
# write:Were All Alone.mscx
# write:Weve Got It Goin On.mscx
# write:Weve Only Just Begun.mscx
# write:What Can I Do.mscx
# write:What Can I Say.mscx
# write:What If God Was One Of Us.mscx
# write:What U See I What U Get.mscx
# write:Whats New Pussycat.mscx
# write:When Can I See You Again.mscx
# write:When Hes Not Around.mscx
# write:When I Come Around.mscx
# write:Where the Boys Are.mscx
# write:Where You Are.mscx
# write:Who Knew.mscx
# write:Who's That Girl.mscx
# write:Will You Still Love Me Tomorrow.mscx
# write:Wind Beneath My Wings.mscx
# write:Winter Wonderland.mscx
# write:Wishing I Was There.mscx
# write:Yesterday.mscx
# write:You And I.mscx
# write:You Give Love A Bad Name.mscx
# write:You Light Up My Life.mscx
# write:You Needed Me.mscx
# write:You Never Done It Like That.mscx
# You Sang to Me.mscx,error
# write:You sexy thing.mscx
# write:Youre No Good.mscx
# write:Youre the One That I Want.mscx
# write:Youve Got A Friend.mscx
# write:Youve Made Me So Very Happy.mscx
# write:再展笑容.mscx
# write:路旁樹.mscx
