# %%
import musicMaker
music = musicMaker.Music('C:/Users/BigData/Desktop/Leave Me Alone Im Lonely.mscx')

# %%
p = music.getChords()

# %%
print p
# Out:
# [0, 0, 0, 0, 'C', 'C', 'C', 'Em', 'Em', 'Am', 'Em', 'Em', 'C', 'C', 'Em', 'Em', 'Em', 'F', 'Dm', 'G', 'C', 'C', 'Em', 'Em', 'Em', 'F', 'Dm', 'G', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'C', 'Em', 'Em', 'F', 'Em', 'Em', 'Am', 'Am', 'G', 'G', 'F', 'F', 'F', 'C', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'C', 'Em', 'Em', 'Am', 'Em', 'Em', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'C', 'Em', 'Em', 'Am', 'Em', 'Em', 'Am', 'C', 'G', 'C', 'F', 'F', 'Em', 'C', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'C', 'C', 'Em', 'Em', 'C', 'C', 'G', 'G', 'F', 'Dm', 'G', 'G', 'C', 'G', 'G', 'Bdim', 'F', 'Dm', 'G', 'G', 'C', 'G', 'F', 'Dm', 'F', 'Dm', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Em', 'Em', 'Am', 'Em', 'Em', 'C', 'C', 'C', 'Em', 'Em', 'Am', 'Em', 'Em', 'G', 'C', 'Em', 'Em', 'Em', 'F', 'Dm', 'G', 'G', 'C', 'Em', 'Em', 'Em', 'F', 'Dm', 'G', 'C'
# ...

# %%
q = music.getPercussions()
# Out:
# Tuplet occurs, ommitting...
# Tuplet occurs, ommitting...
# Tuplet occurs, ommitting...
# Tuplet occurs, ommitting...

# %%
print q
# Out:
# {u'staff_10': {u'measure_18': {'track0': '0.125,42;0.125,42;0.125,38,42;0.125,42;0.125,42;0.125,42;0.125,38,42;0.125,42', u'track37': '0.25,35;0.25,0;0.25,35;0.25,0'}, u'measure_19': {'track0': '0.125,46;0.125,42;0.125,38,42;0.125,42;0.125,42;0.125,42;0.125,38,42;0.125,42', u'track37': '0.25,35;0.25,0;0.25,35;0.25,0'}, u'measure_16': {'track0': '0.125,42;0.125,42;0.125,38,42;0.125,42;0.125,42;0.125,42;0.125,38,42;0.125,42', u'track37': '0.25,35;0.25,0;0.25,35;0.25,0'}, u'measure_17': {'track0': '0.125,42;0.125,42;0.125,38,42;0.125,42;0.125,42;0.125,42;0.125,38,42;0.125,42', u'track37': '0.25,35;0.25,0;0.25,35;0.25,0'}, u'measure_14': {'track0': '0.125,46;0.125,46;0.0078125,46;0.0234375,38,46;0.09375,38,46;0.125,46;0.125,46;0.125,46;0.0078125,38;0.0234375,38,46;0.0078125,38,46;0.0234375,38;0.0625,38;0.0625,38,46;0.0625,38', u'track37': '0.25,35;0.25,35;0.25,35;0.25,35'}, u'measure_15': {'track0': '0.125,49;0.125,42;0.125,38,42;0.125,42;0.125,42;0.125,42;0.125,38,42;0.125,42', u'track3
# ...
